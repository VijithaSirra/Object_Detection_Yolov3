# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ls -la "/content/gdrive/My Drive/darknet"
# Out:
# total 581364
# drwx------ 2 root root      4096 Jan 25 08:13 backup
# -rw------- 1 root root 432811879 Jan 25 06:44 cudnn-10.0-linux-x64-v7.5.0.56.tgz
# -rw------- 1 root root 162482580 Jan 25 08:47 darknet53.conv.74
# drwx------ 2 root root      4096 Jan 25 06:23 Img
# drwx------ 2 root root      4096 Jan 25 08:13 .ipynb_checkpoints
# -rw------- 1 root root       216 Jan 25 08:12 obj.data
# -rw------- 1 root root         7 Jan 25 08:13 obj.names
# -rw------- 1 root root       494 Jan 25 08:13 test.txt
# drwx------ 2 root root      4096 Jan 25 06:21 Train_Images
# -rw------- 1 root root      1041 Jan 25 08:13 Train_txt
# -rw------- 1 root root      1909 Jan 25 08:48 yolov3-tiny.cfg

# %%
# !/usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243

# %%
# !tar -xzvf /content/gdrive/MyDrive/darknet/cudnn-10.0-linux-x64-v7.5.0.56.tgz -C /usr/local/
# !chmod a+r /usr/local/cuda/include/cudnn.h
# Out:
# cuda/include/cudnn.h
# cuda/NVIDIA_SLA_cuDNN_Support.txt
# cuda/lib64/libcudnn.so
# cuda/lib64/libcudnn.so.7
# cuda/lib64/libcudnn.so.7.5.0
# cuda/lib64/libcudnn_static.a

# %%
# !cat /usr/local/cuda/include/cudnn.h | grep CUDNN_MAJOR -A 2
# Out:
# #define CUDNN_MAJOR 7
# #define CUDNN_MINOR 5
# #define CUDNN_PATCHLEVEL 0
# --
# #define CUDNN_VERSION (CUDNN_MAJOR * 1000 + CUDNN_MINOR * 100 + CUDNN_PATCHLEVEL)
#
# #include "driver_types.h"

# %%
# Leave this code uncommented on the very first run of your notebook or if you ever need to recompile darknet again.
# Comment this code on the future runs.
# !git clone https://github.com/kriyeng/darknet/
# %cd darknet

# Check the folder
# !ls

# I have a branch where I have done the changes commented above
# !git checkout feature/google-colab

#Compile Darknet
# !make

#Copies the Darknet compiled version to Google drive
# !cp ./darknet /content/gdrive/My\ Drive/darknet/bin/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 10068, done.
# remote: Total 10068 (delta 0), reused 0 (delta 0), pack-reused 10068
# Receiving objects: 100% (10068/10068), 10.13 MiB | 24.29 MiB/s, done.
# Resolving deltas: 100% (6742/6742), done.
# /content/darknet
# 3rdparty      CMakeLists.txt	      image_yolov3.sh	     scripts
# appveyor.yml  CMakeSettings.json      include		     src
# build	      DarknetConfig.cmake.in  json_mjpeg_streams.sh  video_v2.sh
# build.ps1     darknet.py	      LICENSE		     video_yolov3.sh
# build.sh      darknet_video.py	      Makefile
# cfg	      data		      net_cam_v3.sh
# cmake	      image_yolov2.sh	      README.md
# Branch 'feature/google-colab' set up to track remote branch 'feature/google-colab' from 'origin'.
# Switched to a new branch 'feature/google-colab'
# mkdir -p obj
# mkdir -p backup
# mkdir -p results
# chmod +x *.sh
# g++ -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(mat_cv*, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:896:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# g++ -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/http_stream.cpp -o obj/http_stream.o
# ./src/http_stream.cpp: In member function ‘bool JSON_sender::write(const char*)’:
# ./src/http_stream.cpp:228:21: warning: unused variable ‘n’ [-Wunused-variable]
#                  int n = _write(client, outputbuf, outlen);
#                      ^
# ./src/http_stream.cpp: In member function ‘bool MJPG_sender::write(const cv::Mat&)’:
# ./src/http_stream.cpp:475:23: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#                  if (n < outlen)
#                      ~~^~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/gemm.c -o obj/gemm.o
# ./src/gemm.c: In function ‘convolution_2d’:
# ./src/gemm.c:2016:15: warning: unused variable ‘out_w’ [-Wunused-variable]
#      const int out_w = (w + 2 * pad - ksize) / stride + 1;    // output_width=input_width for stride=1 and pad=1
#                ^~~~~
# ./src/gemm.c:2015:15: warning: unused variable ‘out_h’ [-Wunused-variable]
#      const int out_h = (h + 2 * pad - ksize) / stride + 1;    // output_height=input_height for stride=1 and pad=1
#                ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/utils.c -o obj/utils.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/dark_cuda.c -o obj/dark_cuda.o
# ./src/dark_cuda.c: In function ‘get_cuda_stream’:
# ./src/dark_cuda.c:120:18: warning: unused variable ‘buffer’ [-Wunused-variable]
#              char buffer[256];
#                   ^~~~~~
# ./src/dark_cuda.c: In function ‘get_cuda_memcpy_stream’:
# ./src/dark_cuda.c:141:18: warning: unused variable ‘buffer’ [-Wunused-variable]
#              char buffer[256];
#                   ^~~~~~
# ./src/dark_cuda.c: In function ‘cudnn_handle’:
# ./src/dark_cuda.c:161:23: warning: unused variable ‘status’ [-Wunused-variable]
#          cudnnStatus_t status = cudnnSetStream(handle[i], get_cuda_stream());
#                        ^~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/convolutional_layer.c -o obj/convolutional_layer.o
# ./src/convolutional_layer.c: In function ‘forward_convolutional_layer’:
# ./src/convolutional_layer.c:951:28: warning: unused variable ‘t_intput_size’ [-Wunused-variable]
#                      size_t t_intput_size = binary_transpose_align_input(k, n, state.workspace, &l.t_bit_input, ldb_align, l.bit_align);
#                             ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/list.c -o obj/list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image.c -o obj/image.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/activations.c -o obj/activations.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/im2col.c -o obj/im2col.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/col2im.c -o obj/col2im.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/blas.c -o obj/blas.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/crop_layer.c -o obj/crop_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/dropout_layer.c -o obj/dropout_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/maxpool_layer.c -o obj/maxpool_layer.o
# ./src/maxpool_layer.c: In function ‘cudnn_maxpool_setup’:
# ./src/maxpool_layer.c:26:19: warning: variable ‘maxpool_status’ set but not used [-Wunused-but-set-variable]
#      cudnnStatus_t maxpool_status;
#                    ^~~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/softmax_layer.c -o obj/softmax_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/data.c -o obj/data.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/matrix.c -o obj/matrix.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/network.c -o obj/network.o
# ./src/network.c: In function ‘resize_network’:
# ./src/network.c:511:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess == cudaHostAlloc(&net->input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped))
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:40,
#                  from ./src/network.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/connected_layer.c -o obj/connected_layer.o
# ./src/connected_layer.c: In function ‘forward_connected_layer_gpu’:
# ./src/connected_layer.c:335:11: warning: unused variable ‘one’ [-Wunused-variable]
#      float one = 1;    // alpha[0], beta[0]
#            ^~~
# ./src/connected_layer.c:333:13: warning: unused variable ‘c’ [-Wunused-variable]
#      float * c = l.output_gpu;
#              ^
# ./src/connected_layer.c:332:13: warning: unused variable ‘b’ [-Wunused-variable]
#      float * b = l.weights_gpu;
#              ^
# ./src/connected_layer.c:331:13: warning: unused variable ‘a’ [-Wunused-variable]
#      float * a = state.input;
#              ^
# ./src/connected_layer.c:330:9: warning: unused variable ‘n’ [-Wunused-variable]
#      int n = l.outputs;
#          ^
# ./src/connected_layer.c:329:9: warning: unused variable ‘k’ [-Wunused-variable]
#      int k = l.inputs;
#          ^
# ./src/connected_layer.c:328:9: warning: unused variable ‘m’ [-Wunused-variable]
#      int m = l.batch;
#          ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/cost_layer.c -o obj/cost_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/parser.c -o obj/parser.o
# ./src/parser.c: In function ‘parse_network_cfg_custom’:
# ./src/parser.c:874:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess == cudaHostAlloc(&net.input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped)) net.input_pinned_cpu_flag = 1;
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:40,
#                  from ./src/activations.h:3,
#                  from ./src/activation_layer.h:4,
#                  from ./src/parser.c:6:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/option_list.c -o obj/option_list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/darknet.c -o obj/darknet.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/detection_layer.c -o obj/detection_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/captcha.c -o obj/captcha.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/route_layer.c -o obj/route_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/writing.c -o obj/writing.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/box.c -o obj/box.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/nightmare.c -o obj/nightmare.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/normalization_layer.c -o obj/normalization_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/avgpool_layer.c -o obj/avgpool_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/coco.c -o obj/coco.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/dice.c -o obj/dice.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/yolo.c -o obj/yolo.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/detector.c -o obj/detector.o
# ./src/detector.c: In function ‘validate_detector_map’:
# ./src/detector.c:1008:15: warning: unused variable ‘class_recall’ [-Wunused-variable]
#          float class_recall = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)(truth_classes_count[i] - tp_for_thresh_per_class[i]));
#                ^~~~~~~~~~~~
# ./src/detector.c:1007:15: warning: unused variable ‘class_precision’ [-Wunused-variable]
#          float class_precision = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)fp_for_thresh_per_class[i]);
#                ^~~~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/layer.c -o obj/layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/compare.c -o obj/compare.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/classifier.c -o obj/classifier.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/local_layer.c -o obj/local_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/swag.c -o obj/swag.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/shortcut_layer.c -o obj/shortcut_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/activation_layer.c -o obj/activation_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/rnn_layer.c -o obj/rnn_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/gru_layer.c -o obj/gru_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/rnn.c -o obj/rnn.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/rnn_vid.c -o obj/rnn_vid.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/crnn_layer.c -o obj/crnn_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/demo.c -o obj/demo.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/tag.c -o obj/tag.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/cifar.c -o obj/cifar.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/go.c -o obj/go.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/batchnorm_layer.c -o obj/batchnorm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/art.c -o obj/art.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/region_layer.c -o obj/region_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/reorg_layer.c -o obj/reorg_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/reorg_old_layer.c -o obj/reorg_old_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/super.c -o obj/super.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/voxel.c -o obj/voxel.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/tree.c -o obj/tree.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/yolo_layer.c -o obj/yolo_layer.o
# ./src/yolo_layer.c: In function ‘make_yolo_layer’:
# ./src/yolo_layer.c:58:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.output, batch*l.outputs*sizeof(float), cudaHostRegisterMapped)) l.output_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:40,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c:65:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.delta, batch*l.outputs*sizeof(float), cudaHostRegisterMapped)) l.delta_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:40,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c: In function ‘resize_yolo_layer’:
# ./src/yolo_layer.c:92:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->output, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:40,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c:101:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->delta, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:40,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/upsample_layer.c -o obj/upsample_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/lstm_layer.c -o obj/lstm_layer.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/convolutional_kernels.cu -o obj/convolutional_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/activation_kernels.cu -o obj/activation_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/im2col_kernels.cu -o obj/im2col_kernels.o
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/col2im_kernels.cu -o obj/col2im_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/blas_kernels.cu -o obj/blas_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/crop_layer_kernels.cu -o obj/crop_layer_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/dropout_layer_kernels.cu -o obj/dropout_layer_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/maxpool_layer_kernels.cu -o obj/maxpool_layer_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/network_kernels.cu -o obj/network_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/avgpool_layer_kernels.cu -o obj/avgpool_layer_kernels.o
# g++ -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include obj/image_opencv.o obj/http_stream.o obj/gemm.o obj/utils.o obj/dark_cuda.o obj/convolutional_layer.o obj/list.o obj/image.o obj/activations.o obj/im2col.o obj/col2im.o obj/blas.o obj/crop_layer.o obj/dropout_layer.o obj/maxpool_layer.o obj/softmax_layer.o obj/data.o obj/matrix.o obj/network.o obj/connected_layer.o obj/cost_layer.o obj/parser.o obj/option_list.o obj/darknet.o obj/detection_layer.o obj/captcha.o obj/route_layer.o obj/writing.o obj/box.o obj/nightmare.o obj/normalization_layer.o obj/avgpool_layer.o obj/coco.o obj/dice.o obj/yolo.o obj/detector.o obj/layer.o obj/compare.o obj/classifier.o obj/local_layer.o obj/swag.o obj/shortcut_layer.o obj/activation_layer.o obj/rnn_layer.o obj/gru_layer.o obj/rnn.o obj/rnn_vid.o obj/crnn_layer.o obj/demo.o obj/tag.o obj/cifar.o obj/go.o obj/batchnorm_layer.o obj/art.o obj/region_layer.o obj/reorg_layer.o obj/reorg_old_layer.o obj/super.o obj/voxel.o obj/tree.o obj/yolo_layer.o obj/upsample_layer.o obj/lstm_layer.o obj/convolutional_kernels.o obj/activation_kernels.o obj/im2col_kernels.o obj/col2im_kernels.o obj/blas_kernels.o obj/crop_layer_kernels.o obj/dropout_layer_kernels.o obj/maxpool_layer_kernels.o obj/network_kernels.o obj/avgpool_layer_kernels.o -o darknet -lm -pthread `pkg-config --libs opencv` -L/usr/local/cuda/lib64 -lcuda -lcudart -lcublas -lcurand -L/usr/local/cudnn/lib64 -lcudnn -lstdc++
# cp: cannot create regular file '/content/gdrive/My Drive/darknet/bin/darknet': No such file or directory

# %%
# !./darknet detector train "/content/gdrive/My Drive/darknet/obj.data" "/content/gdrive/My Drive/darknet/yolov3-tiny.cfg" "/content/gdrive/My Drive/darknet/darknet53.conv.74" -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# Loaded: 0.139328 seconds
#
#  4535: 0.177643, 0.278533 avg loss, 0.006250 rate, 0.165250 seconds, 90700 images
# Loaded: 0.116511 seconds
#
#  4536: 0.319053, 0.282585 avg loss, 0.006250 rate, 0.167364 seconds, 90720 images
# Loaded: 0.053098 seconds
#
#  4537: 0.190175, 0.273344 avg loss, 0.006250 rate, 0.180198 seconds, 90740 images
# Loaded: 0.089495 seconds
#
#  4538: 0.323942, 0.278404 avg loss, 0.006250 rate, 0.166433 seconds, 90760 images
# Loaded: 0.071283 seconds
#
#  4539: 0.168065, 0.267370 avg loss, 0.006250 rate, 0.165796 seconds, 90780 images
# Loaded: 0.169343 seconds
#
#  4540: 0.293946, 0.270028 avg loss, 0.006250 rate, 0.172452 seconds, 90800 images
# Resizing
# 352 x 352
#  try to allocate additional workspace_size = 99.87 MB
#  CUDA allocate done!
# Loaded: 0.000044 seconds
#
#  4541: 0.199429, 0.262968 avg loss, 0.006250 rate, 0.087154 seconds, 90820 images
# Loaded: 0.218548 seconds
#
#  4542: 0.266847, 0.263356 avg loss, 0.006250 rate, 0.096461 seconds, 90840 images
# Loaded: 0.134080 seconds
#
#  4543: 0.166954, 0.253716 avg loss, 0.006250 rate, 0.090142 seconds, 90860 images
# Loaded: 0.091135 seconds
#
#  4544: 0.182003, 0.246544 avg loss, 0.006250 rate, 0.094155 seconds, 90880 images
# Loaded: 0.197702 seconds
#
#  4545: 0.167772, 0.238667 avg loss, 0.006250 rate, 0.090715 seconds, 90900 images
# Loaded: 0.110516 seconds
#
#  4546: 0.248349, 0.239635 avg loss, 0.006250 rate, 0.098998 seconds, 90920 images
# Loaded: 0.118872 seconds
#
#  4547: 0.158319, 0.231504 avg loss, 0.006250 rate, 0.092313 seconds, 90940 images
# Loaded: 0.214676 seconds
#
#  4548: 0.109011, 0.219254 avg loss, 0.006250 rate, 0.100645 seconds, 90960 images
# Loaded: 0.114730 seconds
#
#  4549: 0.246056, 0.221935 avg loss, 0.006250 rate, 0.087798 seconds, 90980 images
# Loaded: 0.141745 seconds
#
#  4550: 0.226130, 0.222354 avg loss, 0.006250 rate, 0.092816 seconds, 91000 images
# Resizing
# 416 x 416
#  try to allocate additional workspace_size = 139.49 MB
#  CUDA allocate done!
# Loaded: 0.000047 seconds
#
#  4551: 0.185492, 0.218668 avg loss, 0.006250 rate, 0.128975 seconds, 91020 images
# Loaded: 0.090044 seconds
#
#  4552: 0.179780, 0.214779 avg loss, 0.006250 rate, 0.124357 seconds, 91040 images
# Loaded: 0.182236 seconds
#
#  4553: 0.258887, 0.219190 avg loss, 0.006250 rate, 0.130659 seconds, 91060 images
# Loaded: 0.194302 seconds
#
#  4554: 0.281527, 0.225424 avg loss, 0.006250 rate, 0.134500 seconds, 91080 images
# Loaded: 0.061044 seconds
#
#  4555: 0.206957, 0.223577 avg loss, 0.006250 rate, 0.129538 seconds, 91100 images
# Loaded: 0.147720 seconds
#
#  4556: 0.214608, 0.222680 avg loss, 0.006250 rate, 0.144962 seconds, 91120 images
# Loaded: 0.268871 seconds
#
#  4557: 0.205482, 0.220960 avg loss, 0.006250 rate, 0.135171 seconds, 91140 images
# Loaded: 0.176843 seconds
#
#  4558: 0.196131, 0.218477 avg loss, 0.006250 rate, 0.130017 seconds, 91160 images
# Loaded: 0.061076 seconds
#
#  4559: 0.176356, 0.214265 avg loss, 0.006250 rate, 0.136692 seconds, 91180 images
# Loaded: 0.158757 seconds
#
#  4560: 0.158408, 0.208680 avg loss, 0.006250 rate, 0.132216 seconds, 91200 images
# Resizing
# 480 x 480
#  try to allocate additional workspace_size = 185.70 MB
#  CUDA allocate done!
# Loaded: 0.000068 seconds
#
#  4561: 0.242196, 0.212031 avg loss, 0.006250 rate, 0.163546 seconds, 91220 images
# Loaded: 0.053036 seconds
#
#  4562: 0.167857, 0.207614 avg loss, 0.006250 rate, 0.164084 seconds, 91240 images
# Loaded: 0.088538 seconds
#
#  4563: 0.256785, 0.212531 avg loss, 0.006250 rate, 0.173611 seconds, 91260 images
# Loaded: 0.076333 seconds
#
#  4564: 0.234770, 0.214755 avg loss, 0.006250 rate, 0.175949 seconds, 91280 images
# Loaded: 0.052987 seconds
#
#  4565: 0.235297, 0.216809 avg loss, 0.006250 rate, 0.169914 seconds, 91300 images
# Loaded: 0.072273 seconds
#
#  4566: 0.224288, 0.217557 avg loss, 0.006250 rate, 0.172882 seconds, 91320 images
# Loaded: 0.154832 seconds
#
#  4567: 0.216324, 0.217434 avg loss, 0.006250 rate, 0.192388 seconds, 91340 images
# Loaded: 0.101477 seconds
#
#  4568: 0.288743, 0.224565 avg loss, 0.006250 rate, 0.169158 seconds, 91360 images
# Loaded: 0.139431 seconds
#
#  4569: 0.305430, 0.232651 avg loss, 0.006250 rate, 0.171260 seconds, 91380 images
# Loaded: 0.153002 seconds
#
#  4570: 0.298644, 0.239250 avg loss, 0.006250 rate, 0.151651 seconds, 91400 images
# Resizing
# 384 x 384
#  try to allocate additional workspace_size = 118.85 MB
#  CUDA allocate done!
# Loaded: 0.072732 seconds
#
#  4571: 0.175267, 0.232852 avg loss, 0.006250 rate, 0.108069 seconds, 91420 images
# Loaded: 0.150486 seconds
#
#  4572: 0.232724, 0.232839 avg loss, 0.006250 rate, 0.106471 seconds, 91440 images
# Loaded: 0.225704 seconds
#
#  4573: 0.209138, 0.230469 avg loss, 0.006250 rate, 0.105676 seconds, 91460 images
# Loaded: 0.292674 seconds
#
#  4574: 0.273225, 0.234745 avg loss, 0.006250 rate, 0.112250 seconds, 91480 images
# Loaded: 0.072896 seconds
#
#  4575: 0.242944, 0.235565 avg loss, 0.006250 rate, 0.116204 seconds, 91500 images
# Loaded: 0.101089 seconds
#
#  4576: 0.184242, 0.230432 avg loss, 0.006250 rate, 0.109110 seconds, 91520 images
# Loaded: 0.144507 seconds
#
#  4577: 0.240638, 0.231453 avg loss, 0.006250 rate, 0.117421 seconds, 91540 images
# Loaded: 0.086803 seconds
#
#  4578: 0.195230, 0.227831 avg loss, 0.006250 rate, 0.110590 seconds, 91560 images
# Loaded: 0.175426 seconds
#
#  4579: 0.214685, 0.226516 avg loss, 0.006250 rate, 0.102731 seconds, 91580 images
# Loaded: 0.178454 seconds
#
#  4580: 0.163838, 0.220248 avg loss, 0.006250 rate, 0.108001 seconds, 91600 images
# Resizing
# 448 x 448
#  try to allocate additional workspace_size = 161.77 MB
#  CUDA allocate done!
# Loaded: 0.000044 seconds
#
#  4581: 0.287942, 0.227018 avg loss, 0.006250 rate, 0.139950 seconds, 91620 images
# Loaded: 0.184580 seconds
#
#  4582: 0.207342, 0.225050 avg loss, 0.006250 rate, 0.147664 seconds, 91640 images
# Loaded: 0.179496 seconds
#
#  4583: 0.255262, 0.228071 avg loss, 0.006250 rate, 0.144682 seconds, 91660 images
# Loaded: 0.239610 seconds
#
#  4584: 0.204095, 0.225674 avg loss, 0.006250 rate, 0.140021 seconds, 91680 images
# Loaded: 0.057835 seconds
#
#  4585: 0.253238, 0.228430 avg loss, 0.006250 rate, 0.142261 seconds, 91700 images
# Loaded: 0.104102 seconds
#
#  4586: 0.268324, 0.232419 avg loss, 0.006250 rate, 0.150480 seconds, 91720 images
# Loaded: 0.142860 seconds
#
#  4587: 0.308165, 0.239994 avg loss, 0.006250 rate, 0.156012 seconds, 91740 images
# Loaded: 0.057267 seconds
#
#  4588: 0.265506, 0.242545 avg loss, 0.006250 rate, 0.154853 seconds, 91760 images
# Loaded: 0.079543 seconds
#
#  4589: 0.311492, 0.249440 avg loss, 0.006250 rate, 0.147783 seconds, 91780 images
# Loaded: 0.150027 seconds
#
#  4590: 0.210141, 0.245510 avg loss, 0.006250 rate, 0.152834 seconds, 91800 images
# Resizing
# 480 x 480
#  try to allocate additional workspace_size = 185.70 MB
#  CUDA allocate done!
# Loaded: 0.000039 seconds
#
#  4591: 0.291033, 0.250062 avg loss, 0.006250 rate, 0.158082 seconds, 91820 images
# Loaded: 0.095107 seconds
#
#  4592: 0.323286, 0.257385 avg loss, 0.006250 rate, 0.163231 seconds, 91840 images
# Loaded: 0.143663 seconds
#
#  4593: 0.355633, 0.267209 avg loss, 0.006250 rate, 0.161431 seconds, 91860 images
# Loaded: 0.211679 seconds
#
#  4594: 0.246552, 0.265144 avg loss, 0.006250 rate, 0.157912 seconds, 91880 images
# Loaded: 0.049973 seconds
#
#  4595: 0.350558, 0.273685 avg loss, 0.006250 rate, 0.166413 seconds, 91900 images
# Loaded: 0.073371 seconds
#
#  4596: 0.181404, 0.264457 avg loss, 0.006250 rate, 0.176766 seconds, 91920 images
# Loaded: 0.041778 seconds
#
#  4597: 0.281748, 0.266186 avg loss, 0.006250 rate, 0.177998 seconds, 91940 images
# Loaded: 0.156368 seconds
#
#  4598: 0.306573, 0.270225 avg loss, 0.006250 rate, 0.161215 seconds, 91960 images
# Loaded: 0.241674 seconds
#
#  4599: 0.226653, 0.265868 avg loss, 0.006250 rate, 0.168859 seconds, 91980 images
# Loaded: 0.237555 seconds
#
#  4600: 0.187538, 0.258035 avg loss, 0.006250 rate, 0.161806 seconds, 92000 images
# Saving weights to /content/gdrive/My Drive/darknet/backup/yolov3-tiny_last.weights
# Resizing
# 480 x 480
#  try to allocate additional workspace_size = 185.70 MB
#  CUDA allocate done!
# Loaded: 0.063378 seconds
#
#  4601: 0.290459, 0.261277 avg loss, 0.006250 rate, 0.181694 seconds, 92020 images
# Loaded: 0.100612 seconds
#
#  4602: 0.211077, 0.256257 avg loss, 0.006250 rate, 0.161892 seconds, 92040 images
# Loaded: 0.250150 seconds
#
#  4603: 0.213554, 0.251987 avg loss, 0.006250 rate, 0.159560 seconds, 92060 images
# Loaded: 0.114938 seconds
#
#  4604: 0.192701, 0.246058 avg loss, 0.006250 rate, 0.169134 seconds, 92080 images
# Loaded: 0.146819 seconds
#
#  4605: 0.230674, 0.244520 avg loss, 0.006250 rate, 0.157627 seconds, 92100 images
# Loaded: 0.151158 seconds
#
#  4606: 0.222219, 0.242290 avg loss, 0.006250 rate, 0.181557 seconds, 92120 images
# Loaded: 0.123044 seconds
#
#  4607: 0.195793, 0.237640 avg loss, 0.006250 rate, 0.151807 seconds, 92140 images
# Loaded: 0.147232 seconds
#
#  4608: 0.295576, 0.243434 avg loss, 0.006250 rate, 0.173601 seconds, 92160 images
# Loaded: 0.063374 seconds
#
#  4609: 0.321852, 0.251276 avg loss, 0.006250 rate, 0.173218 seconds, 92180 images
# Loaded: 0.168573 seconds
#
#  4610: 0.290625, 0.255210 avg loss, 0.006250 rate, 0.165224 seconds, 92200 images
# Resizing
# 480 x 480
#  try to allocate additional workspace_size = 185.70 MB
#  CUDA allocate done!
# Loaded: 0.045790 seconds
#
#  4611: 0.263752, 0.256065 avg loss, 0.006250 rate, 0.164003 seconds, 92220 images
# Loaded: 0.165273 seconds
#
#  4612: 0.212030, 0.251661 avg loss, 0.006250 rate, 0.178266 seconds, 92240 images
# Loaded: 0.222981 seconds
#
#  4613: 0.134473, 0.239942 avg loss, 0.006250 rate, 0.171386 seconds, 92260 images
# Loaded: 0.238380 seconds
#
#  4614: 0.226423, 0.238590 avg loss, 0.006250 rate, 0.170263 seconds, 92280 images
# Loaded: 0.294047 seconds
#
#  4615: 0.294607, 0.244192 avg loss, 0.006250 rate, 0.175425 seconds, 92300 images
# Loaded: 0.219830 seconds
#
#  4616: 0.322809, 0.252054 avg loss, 0.006250 rate, 0.152804 seconds, 92320 images
# Loaded: 0.295575 seconds
#
#  4617: 0.199513, 0.246800 avg loss, 0.006250 rate, 0.169042 seconds, 92340 images
# Loaded: 0.134470 seconds
#
#  4618: 0.180796, 0.240199 avg loss, 0.006250 rate, 0.186449 seconds, 92360 images
# Loaded: 0.054036 seconds
#
#  4619: 0.289336, 0.245113 avg loss, 0.006250 rate, 0.158932 seconds, 92380 images
# Loaded: 0.056032 seconds
#
#  4620: 0.212903, 0.241892 avg loss, 0.006250 rate, 0.177915 seconds, 92400 images
# Resizing
# 320 x 320
#  try to allocate additional workspace_size = 82.54 MB
#  CUDA allocate done!
# Loaded: 0.000050 seconds
#
#  4621: 0.241458, 0.241849 avg loss, 0.006250 rate, 0.083136 seconds, 92420 images
# Loaded: 0.168789 seconds
#
#  4622: 0.211212, 0.238785 avg loss, 0.006250 rate, 0.081987 seconds, 92440 images
# Loaded: 0.173418 seconds
#
#  4623: 0.200876, 0.234994 avg loss, 0.006250 rate, 0.076271 seconds, 92460 images
# Loaded: 0.198718 seconds
#
#  4624: 0.275774, 0.239072 avg loss, 0.006250 rate, 0.085064 seconds, 92480 images
# Loaded: 0.095915 seconds
#
#  4625: 0.287652, 0.243930 avg loss, 0.006250 rate, 0.081735 seconds, 92500 images
# Loaded: 0.186853 seconds
#
#  4626: 0.222526, 0.241790 avg loss, 0.006250 rate, 0.078224 seconds, 92520 images
# Loaded: 0.167002 seconds
#
#  4627: 0.210388, 0.238649 avg loss, 0.006250 rate, 0.077396 seconds, 92540 images
# Loaded: 0.229240 seconds
#
#  4628: 0.235418, 0.238326 avg loss, 0.006250 rate, 0.077990 seconds, 92560 images
# Loaded: 0.227703 seconds
#
#  4629: 0.123367, 0.226830 avg loss, 0.006250 rate, 0.076311 seconds, 92580 images
# Loaded: 0.242701 seconds
#
#  4630: 0.163791, 0.220526 avg loss, 0.006250 rate, 0.081371 seconds, 92600 images
# Resizing
# 512 x 512
#  try to allocate additional workspace_size = 211.29 MB
#  CUDA allocate done!
# Loaded: 0.000055 seconds
#
#  4631: 0.372241, 0.235698 avg loss, 0.006250 rate, 0.187052 seconds, 92620 images
# Loaded: 0.031833 seconds
#
#  4632: 0.534484, 0.265577 avg loss, 0.006250 rate, 0.196078 seconds, 92640 images
# Loaded: 0.127843 seconds
#
#  4633: 0.393939, 0.278413 avg loss, 0.006250 rate, 0.213897 seconds, 92660 images
# Loaded: 0.147596 seconds
#
#  4634: 0.489659, 0.299537 avg loss, 0.006250 rate, 0.171099 seconds, 92680 images
# Loaded: 0.143749 seconds
#
#  4635: 0.405369, 0.310121 avg loss, 0.006250 rate, 0.195471 seconds, 92700 images
# Loaded: 0.080178 seconds
#
#  4636: 0.415099, 0.320618 avg loss, 0.006250 rate, 0.201585 seconds, 92720 images
# Loaded: 0.155222 seconds
#
#  4637: 0.342998, 0.322856 avg loss, 0.006250 rate, 0.177412 seconds, 92740 images
# Loaded: 0.038804 seconds
#
#  4638: 0.451287, 0.335699 avg loss, 0.006250 rate, 0.196708 seconds, 92760 images
# Loaded: 0.141203 seconds
#
#  4639: 0.330842, 0.335214 avg loss, 0.006250 rate, 0.218258 seconds, 92780 images
# Loaded: 0.101521 seconds
#
#  4640: 0.399896, 0.341682 avg loss, 0.006250 rate, 0.197674 seconds, 92800 images
# Resizing
# 544 x 544
#  try to allocate additional workspace_size = 238.53 MB
#  CUDA allocate done!
# Loaded: 0.000040 seconds
#
#  4641: 0.339767, 0.341490 avg loss, 0.006250 rate, 0.218358 seconds, 92820 images
# Loaded: 0.000034 seconds
#
#  4642: 0.456596, 0.353001 avg loss, 0.006250 rate, 0.304112 seconds, 92840 images
# Loaded: 0.184015 seconds
#
#  4643: 0.423070, 0.360008 avg loss, 0.006250 rate, 0.257587 seconds, 92860 images
# Loaded: 0.111393 seconds
#
#  4644: 0.316987, 0.355706 avg loss, 0.006250 rate, 0.240965 seconds, 92880 images
# Loaded: 0.096141 seconds
#
#  4645: 0.332942, 0.353430 avg loss, 0.006250 rate, 0.243253 seconds, 92900 images
# Loaded: 0.038006 seconds
#
#  4646: 0.303966, 0.348483 avg loss, 0.006250 rate, 0.244203 seconds, 92920 images
# Loaded: 0.000036 seconds
#
#  4647: 0.402391, 0.353874 avg loss, 0.006250 rate, 0.293495 seconds, 92940 images
# Loaded: 0.060500 seconds
#
#  4648: 0.331013, 0.351588 avg loss, 0.006250 rate, 0.245104 seconds, 92960 images
# Loaded: 0.047684 seconds
#
#  4649: 0.404565, 0.356886 avg loss, 0.006250 rate, 0.261026 seconds, 92980 images
# Loaded: 0.081309 seconds
#
#  4650: 0.385737, 0.359771 avg loss, 0.006250 rate, 0.230694 seconds, 93000 images
# Resizing
# 480 x 480
#  try to allocate additional workspace_size = 185.70 MB
#  CUDA allocate done!
# Loaded: 0.222860 seconds
#
#  4651: 0.329793, 0.356773 avg loss, 0.006250 rate, 0.162892 seconds, 93020 images
# Loaded: 0.122009 seconds
#
#  4652: 0.383223, 0.359418 avg loss, 0.006250 rate, 0.172632 seconds, 93040 images
# Loaded: 0.074829 seconds
#
#  4653: 0.297871, 0.353263 avg loss, 0.006250 rate, 0.179516 seconds, 93060 images
# Loaded: 0.180926 seconds
#
#  4654: 0.178352, 0.335772 avg loss, 0.006250 rate, 0.165818 seconds, 93080 images
# Loaded: 0.092068 seconds
#
#  4655: 0.311759, 0.333371 avg loss, 0.006250 rate, 0.157731 seconds, 93100 images
# Loaded: 0.087044 seconds
#
#  4656: 0.278042, 0.327838 avg loss, 0.006250 rate, 0.170571 seconds, 93120 images
# Loaded: 0.060125 seconds
#
#  4657: 0.345759, 0.329630 avg loss, 0.006250 rate, 0.175081 seconds, 93140 images
# Loaded: 0.184282 seconds
#
#  4658: 0.202958, 0.316963 avg loss, 0.006250 rate, 0.159757 seconds, 93160 images
# Loaded: 0.168478 seconds
#
#  4659: 0.239344, 0.309201 avg loss, 0.006250 rate, 0.175380 seconds, 93180 images
# Loaded: 0.132785 seconds
#
#  4660: 0.160938, 0.294375 avg loss, 0.006250 rate, 0.153729 seconds, 93200 images
# Resizing
# 576 x 576
#  try to allocate additional workspace_size = 267.41 MB
#  CUDA allocate done!
# Loaded: 0.000040 seconds
#
#  4661: 0.562797, 0.321217 avg loss, 0.006250 rate, 0.248057 seconds, 93220 images
# Loaded: 0.069828 seconds
#
#  4662: 0.475717, 0.336667 avg loss, 0.006250 rate, 0.295107 seconds, 93240 images
# Loaded: 0.137670 seconds
#
#  4663: 0.490704, 0.352071 avg loss, 0.006250 rate, 0.273267 seconds, 93260 images
# Loaded: 0.121516 seconds
#
#  4664: 0.453851, 0.362249 avg loss, 0.006250 rate, 0.283172 seconds, 93280 images
# Loaded: 0.000033 seconds
#
#  4665: 0.453579, 0.371382 avg loss, 0.006250 rate, 0.315636 seconds, 93300 images
# Loaded: 0.178157 seconds
#
#  4666: 0.406706, 0.374914 avg loss, 0.006250 rate, 0.276705 seconds, 93320 images
# Loaded: 0.029885 seconds
#
#  4667: 0.324865, 0.369909 avg loss, 0.006250 rate, 0.284557 seconds, 93340 images
# Loaded: 0.138611 seconds
#
#  4668: 0.369091, 0.369827 avg loss, 0.006250 rate, 0.271207 seconds, 93360 images
# Loaded: 0.060422 seconds
#
#  4669: 0.307829, 0.363628 avg loss, 0.006250 rate, 0.270699 seconds, 93380 images
# Loaded: 0.029187 seconds
#
#  4670: 0.498595, 0.377124 avg loss, 0.006250 rate, 0.286838 seconds, 93400 images
# Resizing
# 416 x 416
#  try to allocate additional workspace_size = 139.49 MB
#  CUDA allocate done!
# Loaded: 0.000043 seconds
#
#  4671: 0.326926, 0.372104 avg loss, 0.006250 rate, 0.146871 seconds, 93420 images
# Loaded: 0.155818 seconds
#
#  4672: 0.296998, 0.364594 avg loss, 0.006250 rate, 0.125150 seconds, 93440 images
# Loaded: 0.165375 seconds
#
#  4673: 0.237043, 0.351839 avg loss, 0.006250 rate, 0.133264 seconds, 93460 images
# Loaded: 0.181376 seconds
#
#  4674: 0.283549, 0.345010 avg loss, 0.006250 rate, 0.142601 seconds, 93480 images
# Loaded: 0.126467 seconds
#
#  4675: 0.327363, 0.343245 avg loss, 0.006250 rate, 0.135113 seconds, 93500 images
# Loaded: 0.194803 seconds
#
#  4676: 0.197885, 0.328709 avg loss, 0.006250 rate, 0.138103 seconds, 93520 images
# Loaded: 0.156428 seconds
#
#  4677: 0.286879, 0.324526 avg loss, 0.006250 rate, 0.128745 seconds, 93540 images
# Loaded: 0.126392 seconds
#
#  4678: 0.272504, 0.319324 avg loss, 0.006250 rate, 0.130408 seconds, 93560 images
# Loaded: 0.053146 seconds
#
#  4679: 0.232918, 0.310683 avg loss, 0.006250 rate, 0.144529 seconds, 93580 images
# Loaded: 0.098277 seconds
#
#  4680: 0.173875, 0.297002 avg loss, 0.006250 rate, 0.135463 seconds, 93600 images
# Resizing
# 544 x 544
#  try to allocate additional workspace_size = 238.53 MB
#  CUDA allocate done!
# Loaded: 0.000046 seconds
#
#  4681: 0.260927, 0.293395 avg loss, 0.006250 rate, 0.267238 seconds, 93620 images
# Loaded: 0.041401 seconds
#
#  4682: 0.358681, 0.299923 avg loss, 0.006250 rate, 0.250511 seconds, 93640 images
# Loaded: 0.061921 seconds
#
#  4683: 0.361668, 0.306098 avg loss, 0.006250 rate, 0.228194 seconds, 93660 images
# Loaded: 0.125945 seconds
#
#  4684: 0.343063, 0.309794 avg loss, 0.006250 rate, 0.247206 seconds, 93680 images
# Loaded: 0.139228 seconds
#
#  4685: 0.324095, 0.311224 avg loss, 0.006250 rate, 0.254136 seconds, 93700 images
# Loaded: 0.143885 seconds
#
#  4686: 0.398362, 0.319938 avg loss, 0.006250 rate, 0.243546 seconds, 93720 images
# Loaded: 0.019514 seconds
#
#  4687: 0.418388, 0.329783 avg loss, 0.006250 rate, 0.260141 seconds, 93740 images
# Loaded: 0.040315 seconds
#
#  4688: 0.307489, 0.327554 avg loss, 0.006250 rate, 0.244977 seconds, 93760 images
# Loaded: 0.061921 seconds
#
#  4689: 0.413031, 0.336101 avg loss, 0.006250 rate, 0.243773 seconds, 93780 images
# Loaded: 0.052067 seconds
#
#  4690: 0.407250, 0.343216 avg loss, 0.006250 rate, 0.245709 seconds, 93800 images
# Resizing
# 352 x 352
#  try to allocate additional workspace_size = 99.87 MB
#  CUDA allocate done!
# Loaded: 0.000037 seconds
#
#  4691: 0.195334, 0.328428 avg loss, 0.006250 rate, 0.089252 seconds, 93820 images
# Loaded: 0.126733 seconds
#
#  4692: 0.303717, 0.325957 avg loss, 0.006250 rate, 0.104161 seconds, 93840 images
# Loaded: 0.111065 seconds
#
#  4693: 0.157899, 0.309151 avg loss, 0.006250 rate, 0.093448 seconds, 93860 images
# Loaded: 0.172368 seconds
#
#  4694: 0.276340, 0.305870 avg loss, 0.006250 rate, 0.101377 seconds, 93880 images
# Loaded: 0.158231 seconds
#
#  4695: 0.250278, 0.300311 avg loss, 0.006250 rate, 0.089625 seconds, 93900 images
# Loaded: 0.164889 seconds
#
#  4696: 0.238299, 0.294110 avg loss, 0.006250 rate, 0.093595 seconds, 93920 images
# Loaded: 0.109418 seconds
#
#  4697: 0.233311, 0.288030 avg loss, 0.006250 rate, 0.090782 seconds, 93940 images
# Loaded: 0.163780 seconds
#
#  4698: 0.177165, 0.276943 avg loss, 0.006250 rate, 0.098122 seconds, 93960 images
# Loaded: 0.150357 seconds
#
#  4699: 0.197871, 0.269036 avg loss, 0.006250 rate, 0.091356 seconds, 93980 images
# Loaded: 0.191435 seconds
#
#  4700: 0.256326, 0.267765 avg loss, 0.006250 rate, 0.092579 seconds, 94000 images
# Saving weights to /content/gdrive/My Drive/darknet/backup/yolov3-tiny_last.weights
# Resizing
# 576 x 576
#  try to allocate additional workspace_size = 267.41 MB
#  CUDA allocate done!
# Loaded: 0.000045 seconds
#
#  4701: 0.463866, 0.287375 avg loss, 0.006250 rate, 0.251762 seconds, 94020 images
# Loaded: 0.119459 seconds
#
#  4702: 0.475451, 0.306183 avg loss, 0.006250 rate, 0.267175 seconds, 94040 images
# Loaded: 0.104467 seconds
#
#  4703: 0.519980, 0.327563 avg loss, 0.006250 rate, 0.261818 seconds, 94060 images
# Loaded: 0.031686 seconds
#
#  4704: 0.507655, 0.345572 avg loss, 0.006250 rate, 0.299585 seconds, 94080 images
# Loaded: 0.067841 seconds
#
#  4705: 0.501873, 0.361202 avg loss, 0.006250 rate, 0.286023 seconds, 94100 images
# Loaded: 0.014985 seconds
#
#  4706: 0.370135, 0.362095 avg loss, 0.006250 rate, 0.287925 seconds, 94120 images
# Loaded: 0.116088 seconds
#
#  4707: 0.454365, 0.371322 avg loss, 0.006250 rate, 0.275270 seconds, 94140 images
# Loaded: 0.081525 seconds
#
#  4708: 0.451956, 0.379385 avg loss, 0.006250 rate, 0.273606 seconds, 94160 images
# Loaded: 0.000040 seconds
#
#  4709: 0.531888, 0.394636 avg loss, 0.006250 rate, 0.339703 seconds, 94180 images
# Loaded: 0.011617 seconds
#
#  4710: 0.373573, 0.392529 avg loss, 0.006250 rate, 0.306854 seconds, 94200 images
# Resizing
# 576 x 576
#  try to allocate additional workspace_size = 267.41 MB
#  CUDA allocate done!
# Loaded: 0.021837 seconds
#
#  4711: 0.446571, 0.397934 avg loss, 0.006250 rate, 0.270679 seconds, 94220 images
# Loaded: 0.072139 seconds
#
#  4712: 0.430972, 0.401237 avg loss, 0.006250 rate, 0.283993 seconds, 94240 images
# Loaded: 0.072794 seconds
#
#  4713: 0.317114, 0.392825 avg loss, 0.006250 rate, 0.265067 seconds, 94260 images
# Loaded: 0.023012 seconds
#
#  4714: 0.421835, 0.395726 avg loss, 0.006250 rate, 0.281664 seconds, 94280 images
# Loaded: 0.065190 seconds
#
#  4715: 0.397294, 0.395883 avg loss, 0.006250 rate, 0.259682 seconds, 94300 images
# Loaded: 0.031334 seconds
#
#  4716: 0.421778, 0.398472 avg loss, 0.006250 rate, 0.283079 seconds, 94320 images
# Loaded: 0.083291 seconds
#
#  4717: 0.470514, 0.405676 avg loss, 0.006250 rate, 0.265810 seconds, 94340 images
# Loaded: 0.004727 seconds
#
#  4718: 0.405171, 0.405626 avg loss, 0.006250 rate, 0.311824 seconds, 94360 images
# Loaded: 0.093879 seconds
#
#  4719: 0.381623, 0.403226 avg loss, 0.006250 rate, 0.287413 seconds, 94380 images
# Loaded: 0.100009 seconds
#
#  4720: 0.398077, 0.402711 avg loss, 0.006250 rate, 0.276031 seconds, 94400 images
# Resizing
# 320 x 320
#  try to allocate additional workspace_size = 82.54 MB
#  CUDA allocate done!
# Loaded: 0.000039 seconds
#
#  4721: 0.235559, 0.385996 avg loss, 0.006250 rate, 0.073489 seconds, 94420 images
# Loaded: 0.165462 seconds
#
#  4722: 0.278365, 0.375233 avg loss, 0.006250 rate, 0.076652 seconds, 94440 images
# Loaded: 0.122170 seconds
#
#  4723: 0.247228, 0.362432 avg loss, 0.006250 rate, 0.073212 seconds, 94460 images
# Loaded: 0.118776 seconds
#
#  4724: 0.289882, 0.355177 avg loss, 0.006250 rate, 0.080889 seconds, 94480 images
# Loaded: 0.176253 seconds
#
#  4725: 0.281125, 0.347772 avg loss, 0.006250 rate, 0.085182 seconds, 94500 images
# Loaded: 0.099899 seconds
#
#  4726: 0.209274, 0.333922 avg loss, 0.006250 rate, 0.081918 seconds, 94520 images
# Loaded: 0.177550 seconds
#
#  4727: 0.261658, 0.326696 avg loss, 0.006250 rate, 0.080034 seconds, 94540 images
# Loaded: 0.232883 seconds
#
#  4728: 0.239288, 0.317955 avg loss, 0.006250 rate, 0.087226 seconds, 94560 images
# Loaded: 0.178492 seconds
#
#  4729: 0.198647, 0.306024 avg loss, 0.006250 rate, 0.086212 seconds, 94580 images
# Loaded: 0.257114 seconds
#
#  4730: 0.231975, 0.298619 avg loss, 0.006250 rate, 0.079077 seconds, 94600 images
# Resizing
# 480 x 480
#  try to allocate additional workspace_size = 185.70 MB
#  CUDA allocate done!
# Loaded: 0.000042 seconds
#
#  4731: 0.369262, 0.305684 avg loss, 0.006250 rate, 0.157751 seconds, 94620 images
# Loaded: 0.119572 seconds
#
#  4732: 0.226195, 0.297735 avg loss, 0.006250 rate, 0.168198 seconds, 94640 images
# Loaded: 0.161313 seconds
#
#  4733: 0.318341, 0.299795 avg loss, 0.006250 rate, 0.156696 seconds, 94660 images
# Loaded: 0.132156 seconds
#
#  4734: 0.248191, 0.294635 avg loss, 0.006250 rate, 0.165220 seconds, 94680 images
# Loaded: 0.102439 seconds
#
#  4735: 0.299806, 0.295152 avg loss, 0.006250 rate, 0.173209 seconds, 94700 images
# Loaded: 0.107507 seconds
#
#  4736: 0.388790, 0.304516 avg loss, 0.006250 rate, 0.178479 seconds, 94720 images
# Loaded: 0.129703 seconds
#
#  4737: 0.321536, 0.306218 avg loss, 0.006250 rate, 0.170536 seconds, 94740 images
# Loaded: 0.111235 seconds
#
#  4738: 0.199730, 0.295569 avg loss, 0.006250 rate, 0.176269 seconds, 94760 images
# Loaded: 0.120911 seconds
#
#  4739: 0.294664, 0.295479 avg loss, 0.006250 rate, 0.166241 seconds, 94780 images
# Loaded: 0.103652 seconds
#
#  4740: 0.252578, 0.291189 avg loss, 0.006250 rate, 0.168531 seconds, 94800 images
# Resizing
# 352 x 352
#  try to allocate additional workspace_size = 99.87 MB
#  CUDA allocate done!
# Loaded: 0.193376 seconds
#
#  4741: 0.152741, 0.277344 avg loss, 0.006250 rate, 0.093778 seconds, 94820 images
# Loaded: 0.200599 seconds
#
#  4742: 0.128153, 0.262425 avg loss, 0.006250 rate, 0.093343 seconds, 94840 images
# Loaded: 0.144058 seconds
#
#  4743: 0.260356, 0.262218 avg loss, 0.006250 rate, 0.092534 seconds, 94860 images
# Loaded: 0.246153 seconds
#
#  4744: 0.128088, 0.248805 avg loss, 0.006250 rate, 0.093053 seconds, 94880 images
# Loaded: 0.155183 seconds
#
#  4745: 0.208668, 0.244791 avg loss, 0.006250 rate, 0.087232 seconds, 94900 images
# Loaded: 0.215104 seconds
#
#  4746: 0.168070, 0.237119 avg loss, 0.006250 rate, 0.089698 seconds, 94920 images
# Loaded: 0.149211 seconds
#
#  4747: 0.188355, 0.232243 avg loss, 0.006250 rate, 0.087280 seconds, 94940 images
# Loaded: 0.113102 seconds
#
#  4748: 0.220366, 0.231055 avg loss, 0.006250 rate, 0.100799 seconds, 94960 images
# Loaded: 0.233212 seconds
#
#  4749: 0.133513, 0.221301 avg loss, 0.006250 rate, 0.095839 seconds, 94980 images
# Loaded: 0.142844 seconds
#
#  4750: 0.113992, 0.210570 avg loss, 0.006250 rate, 0.088831 seconds, 95000 images
# Resizing
# 448 x 448
#  try to allocate additional workspace_size = 161.77 MB
#  CUDA allocate done!
# Loaded: 0.000039 seconds
#
#  4751: 0.198997, 0.209413 avg loss, 0.006250 rate, 0.143593 seconds, 95020 images
# Loaded: 0.128111 seconds
#
#  4752: 0.354724, 0.223944 avg loss, 0.006250 rate, 0.161474 seconds, 95040 images
# Loaded: 0.158381 seconds
#
#  4753: 0.192819, 0.220831 avg loss, 0.006250 rate, 0.144350 seconds, 95060 images
# Loaded: 0.183263 seconds
#
#  4754: 0.326411, 0.231389 avg loss, 0.006250 rate, 0.146861 seconds, 95080 images
# Loaded: 0.110429 seconds
#
#  4755: 0.195464, 0.227797 avg loss, 0.006250 rate, 0.151386 seconds, 95100 images
# Loaded: 0.155067 seconds
#
#  4756: 0.200953, 0.225112 avg loss, 0.006250 rate, 0.155906 seconds, 95120 images
# Loaded: 0.125356 seconds
#
#  4757: 0.269240, 0.229525 avg loss, 0.006250 rate, 0.155004 seconds, 95140 images
# Loaded: 0.056260 seconds
#
#  4758: 0.198223, 0.226395 avg loss, 0.006250 rate, 0.142937 seconds, 95160 images
# Loaded: 0.101881 seconds
#
#  4759: 0.333415, 0.237097 avg loss, 0.006250 rate, 0.141598 seconds, 95180 images
# Loaded: 0.153840 seconds
#
#  4760: 0.257396, 0.239127 avg loss, 0.006250 rate, 0.153757 seconds, 95200 images
# Resizing
# 352 x 352
#  try to allocate additional workspace_size = 99.87 MB
#  CUDA allocate done!
# Loaded: 0.065601 seconds
#
#  4761: 0.165087, 0.231723 avg loss, 0.006250 rate, 0.100295 seconds, 95220 images
# Loaded: 0.174530 seconds
#
#  4762: 0.141538, 0.222704 avg loss, 0.006250 rate, 0.091211 seconds, 95240 images
# Loaded: 0.201125 seconds
#
#  4763: 0.189577, 0.219392 avg loss, 0.006250 rate, 0.091566 seconds, 95260 images
# Loaded: 0.089710 seconds
#
#  4764: 0.139196, 0.211372 avg loss, 0.006250 rate, 0.090577 seconds, 95280 images
# Loaded: 0.107486 seconds
#
#  4765: 0.141535, 0.204388 avg loss, 0.006250 rate, 0.092022 seconds, 95300 images
# Loaded: 0.218519 seconds
#
#  4766: 0.176157, 0.201565 avg loss, 0.006250 rate, 0.102754 seconds, 95320 images
# Loaded: 0.127032 seconds
#
#  4767: 0.224926, 0.203901 avg loss, 0.006250 rate, 0.090922 seconds, 95340 images
# Loaded: 0.136293 seconds
#
#  4768: 0.157351, 0.199246 avg loss, 0.006250 rate, 0.092634 seconds, 95360 images
# Loaded: 0.174099 seconds
#
#  4769: 0.207775, 0.200099 avg loss, 0.006250 rate, 0.088142 seconds, 95380 images
# Loaded: 0.126662 seconds
#
#  4770: 0.183393, 0.198429 avg loss, 0.006250 rate, 0.088222 seconds, 95400 images
# Resizing
# 480 x 480
#  try to allocate additional workspace_size = 185.70 MB
#  CUDA allocate done!
# Loaded: 0.000050 seconds
#
#  4771: 0.160520, 0.194638 avg loss, 0.006250 rate, 0.205897 seconds, 95420 images
# Loaded: 0.043969 seconds
#
#  4772: 0.157050, 0.190879 avg loss, 0.006250 rate, 0.160899 seconds, 95440 images
# Loaded: 0.041397 seconds
#
#  4773: 0.307158, 0.202507 avg loss, 0.006250 rate, 0.168594 seconds, 95460 images
# Loaded: 0.104253 seconds
#
#  4774: 0.377270, 0.219983 avg loss, 0.006250 rate, 0.165744 seconds, 95480 images
# Loaded: 0.112446 seconds
#
#  4775: 0.314142, 0.229399 avg loss, 0.006250 rate, 0.167557 seconds, 95500 images
# Loaded: 0.087752 seconds
#
#  4776: 0.317288, 0.238188 avg loss, 0.006250 rate, 0.176581 seconds, 95520 images
# Loaded: 0.095446 seconds
#
#  4777: 0.232101, 0.237579 avg loss, 0.006250 rate, 0.175251 seconds, 95540 images
# Loaded: 0.099781 seconds
#
#  4778: 0.225547, 0.236376 avg loss, 0.006250 rate, 0.159492 seconds, 95560 images
# Loaded: 0.215423 seconds
#
#  4779: 0.322759, 0.245014 avg loss, 0.006250 rate, 0.152639 seconds, 95580 images
# Loaded: 0.081086 seconds
#
#  4780: 0.236272, 0.244140 avg loss, 0.006250 rate, 0.186830 seconds, 95600 images
# Resizing
# 480 x 480
#  try to allocate additional workspace_size = 185.70 MB
#  CUDA allocate done!
# Loaded: 0.118390 seconds
#
#  4781: 0.205506, 0.240277 avg loss, 0.006250 rate, 0.158023 seconds, 95620 images
# Loaded: 0.079344 seconds
#
#  4782: 0.266872, 0.242936 avg loss, 0.006250 rate, 0.169900 seconds, 95640 images
# Loaded: 0.175715 seconds
#
#  4783: 0.146147, 0.233257 avg loss, 0.006250 rate, 0.170634 seconds, 95660 images
# Loaded: 0.100204 seconds
#
#  4784: 0.282825, 0.238214 avg loss, 0.006250 rate, 0.170367 seconds, 95680 images
# Loaded: 0.045907 seconds
#
#  4785: 0.210061, 0.235399 avg loss, 0.006250 rate, 0.169587 seconds, 95700 images
# Loaded: 0.101261 seconds
#
#  4786: 0.253957, 0.237255 avg loss, 0.006250 rate, 0.163908 seconds, 95720 images
# Loaded: 0.079027 seconds
#
#  4787: 0.277587, 0.241288 avg loss, 0.006250 rate, 0.166649 seconds, 95740 images
# Loaded: 0.114967 seconds
#
#  4788: 0.347797, 0.251939 avg loss, 0.006250 rate, 0.177998 seconds, 95760 images
# Loaded: 0.006552 seconds
#
#  4789: 0.254422, 0.252187 avg loss, 0.006250 rate, 0.213920 seconds, 95780 images
# Loaded: 0.114791 seconds
#
#  4790: 0.161239, 0.243092 avg loss, 0.006250 rate, 0.181117 seconds, 95800 images
# Resizing
# 480 x 480
#  try to allocate additional workspace_size = 185.70 MB
#  CUDA allocate done!
# Loaded: 0.028358 seconds
#
#  4791: 0.215115, 0.240295 avg loss, 0.006250 rate, 0.166361 seconds, 95820 images
# Loaded: 0.073497 seconds
#
#  4792: 0.221481, 0.238413 avg loss, 0.006250 rate, 0.169372 seconds, 95840 images
# Loaded: 0.215157 seconds
#
#  4793: 0.297978, 0.244370 avg loss, 0.006250 rate, 0.173620 seconds, 95860 images
# Loaded: 0.175069 seconds
#
#  4794: 0.189159, 0.238849 avg loss, 0.006250 rate, 0.181953 seconds, 95880 images
# Loaded: 0.129207 seconds
#
#  4795: 0.278340, 0.242798 avg loss, 0.006250 rate, 0.169899 seconds, 95900 images
# Loaded: 0.089557 seconds
#
#  4796: 0.305307, 0.249049 avg loss, 0.006250 rate, 0.176533 seconds, 95920 images
# Loaded: 0.167134 seconds
#
#  4797: 0.236930, 0.247837 avg loss, 0.006250 rate, 0.155239 seconds, 95940 images
# Loaded: 0.101483 seconds
#
#  4798: 0.227840, 0.245837 avg loss, 0.006250 rate, 0.168035 seconds, 95960 images
# Loaded: 0.017204 seconds
#
#  4799: 0.231442, 0.244398 avg loss, 0.006250 rate, 0.186357 seconds, 95980 images
# Loaded: 0.243392 seconds
#
#  4800: 0.280186, 0.247976 avg loss, 0.006250 rate, 0.173637 seconds, 96000 images
# Saving weights to /content/gdrive/My Drive/darknet/backup/yolov3-tiny_last.weights
# Resizing
# 352 x 352
#  try to allocate additional workspace_size = 99.87 MB
#  CUDA allocate done!
# Loaded: 0.154729 seconds
#
#  4801: 0.126912, 0.235870 avg loss, 0.006250 rate, 0.094282 seconds, 96020 images
# Loaded: 0.122317 seconds
#
#  4802: 0.200570, 0.232340 avg loss, 0.006250 rate, 0.103660 seconds, 96040 images
# Loaded: 0.074956 seconds
#
#  4803: 0.165790, 0.225685 avg loss, 0.006250 rate, 0.106352 seconds, 96060 images
# Loaded: 0.121359 seconds
#
#  4804: 0.224210, 0.225537 avg loss, 0.006250 rate, 0.086225 seconds, 96080 images
# Loaded: 0.138081 seconds
#
#  4805: 0.161165, 0.219100 avg loss, 0.006250 rate, 0.094045 seconds, 96100 images
# Loaded: 0.169662 seconds
#
#  4806: 0.204443, 0.217634 avg loss, 0.006250 rate, 0.090307 seconds, 96120 images
# Loaded: 0.157619 seconds
#
#  4807: 0.197948, 0.215666 avg loss, 0.006250 rate, 0.084597 seconds, 96140 images
# Loaded: 0.119346 seconds
#
#  4808: 0.146083, 0.208708 avg loss, 0.006250 rate, 0.105017 seconds, 96160 images
# Loaded: 0.125555 seconds
#
#  4809: 0.150324, 0.202869 avg loss, 0.006250 rate, 0.093849 seconds, 96180 images
# Loaded: 0.181861 seconds
#
#  4810: 0.170801, 0.199662 avg loss, 0.006250 rate, 0.088929 seconds, 96200 images
# Resizing
# 416 x 416
#  try to allocate additional workspace_size = 139.49 MB
#  CUDA allocate done!
# Loaded: 0.000047 seconds
#
#  4811: 0.253247, 0.205021 avg loss, 0.006250 rate, 0.147661 seconds, 96220 images
# Loaded: 0.125317 seconds
#
#  4812: 0.252092, 0.209728 avg loss, 0.006250 rate, 0.144733 seconds, 96240 images
# Loaded: 0.090557 seconds
#
#  4813: 0.192252, 0.207980 avg loss, 0.006250 rate, 0.132088 seconds, 96260 images
# Loaded: 0.111783 seconds
#
#  4814: 0.169382, 0.204121 avg loss, 0.006250 rate, 0.142388 seconds, 96280 images
# Loaded: 0.152357 seconds
#
#  4815: 0.182173, 0.201926 avg loss, 0.006250 rate, 0.132909 seconds, 96300 images
# Loaded: 0.087232 seconds
#
#  4816: 0.136013, 0.195335 avg loss, 0.006250 rate, 0.125083 seconds, 96320 images
# Loaded: 0.226163 seconds
#
#  4817: 0.195178, 0.195319 avg loss, 0.006250 rate, 0.131785 seconds, 96340 images
# Loaded: 0.025805 seconds
#
#  4818: 0.223450, 0.198132 avg loss, 0.006250 rate, 0.145543 seconds, 96360 images
# Loaded: 0.135797 seconds
#
#  4819: 0.177586, 0.196077 avg loss, 0.006250 rate, 0.135421 seconds, 96380 images
# Loaded: 0.077156 seconds
#
#  4820: 0.198019, 0.196272 avg loss, 0.006250 rate, 0.142396 seconds, 96400 images
# Resizing
# 384 x 384
#  try to allocate additional workspace_size = 118.85 MB
#  CUDA allocate done!
# Loaded: 0.190428 seconds
#
#  4821: 0.144249, 0.191069 avg loss, 0.006250 rate, 0.104202 seconds, 96420 images
# Loaded: 0.083907 seconds
#
#  4822: 0.124175, 0.184380 avg loss, 0.006250 rate, 0.099225 seconds, 96440 images
# Loaded: 0.226339 seconds
#
#  4823: 0.220698, 0.188012 avg loss, 0.006250 rate, 0.108390 seconds, 96460 images
# Loaded: 0.179232 seconds
#
#  4824: 0.122931, 0.181504 avg loss, 0.006250 rate, 0.104262 seconds, 96480 images
# Loaded: 0.089677 seconds
#
#  4825: 0.172593, 0.180613 avg loss, 0.006250 rate, 0.117526 seconds, 96500 images
# Loaded: 0.105482 seconds
#
#  4826: 0.162215, 0.178773 avg loss, 0.006250 rate, 0.111722 seconds, 96520 images
# Loaded: 0.167606 seconds
#
#  4827: 0.144691, 0.175365 avg loss, 0.006250 rate, 0.106567 seconds, 96540 images
# Loaded: 0.160833 seconds
#
#  4828: 0.174406, 0.175269 avg loss, 0.006250 rate, 0.105077 seconds, 96560 images
# Loaded: 0.240154 seconds
#
#  4829: 0.211696, 0.178911 avg loss, 0.006250 rate, 0.113808 seconds, 96580 images
# Loaded: 0.157524 seconds
#
#  4830: 0.221208, 0.183141 avg loss, 0.006250 rate, 0.105862 seconds, 96600 images
# Resizing
# 352 x 352
#  try to allocate additional workspace_size = 99.87 MB
#  CUDA allocate done!
# Loaded: 0.098010 seconds
#
#  4831: 0.159060, 0.180733 avg loss, 0.006250 rate, 0.086183 seconds, 96620 images
# Loaded: 0.100907 seconds
#
#  4832: 0.155838, 0.178244 avg loss, 0.006250 rate, 0.095850 seconds, 96640 images
# Loaded: 0.074155 seconds
#
#  4833: 0.135002, 0.173919 avg loss, 0.006250 rate, 0.093752 seconds, 96660 images
# Loaded: 0.051119 seconds
#
#  4834: 0.149812, 0.171509 avg loss, 0.006250 rate, 0.091817 seconds, 96680 images
# Loaded: 0.266650 seconds
#
#  4835: 0.210224, 0.175380 avg loss, 0.006250 rate, 0.092903 seconds, 96700 images
# Loaded: 0.137642 seconds
#
#  4836: 0.108610, 0.168703 avg loss, 0.006250 rate, 0.095798 seconds, 96720 images
# Loaded: 0.091199 seconds
#
#  4837: 0.150138, 0.166847 avg loss, 0.006250 rate, 0.089784 seconds, 96740 images
# Loaded: 0.172847 seconds
#
#  4838: 0.095024, 0.159664 avg loss, 0.006250 rate, 0.088040 seconds, 96760 images
# Loaded: 0.201798 seconds
#
#  4839: 0.101325, 0.153830 avg loss, 0.006250 rate, 0.087052 seconds, 96780 images
# Loaded: 0.139153 seconds
#
#  4840: 0.169220, 0.155369 avg loss, 0.006250 rate, 0.090372 seconds, 96800 images
# Resizing
# 384 x 384
#  try to allocate additional workspace_size = 118.85 MB
#  CUDA allocate done!
# Loaded: 0.000043 seconds
#
#  4841: 0.216184, 0.161451 avg loss, 0.006250 rate, 0.113364 seconds, 96820 images
# Loaded: 0.246410 seconds
#
#  4842: 0.177183, 0.163024 avg loss, 0.006250 rate, 0.111081 seconds, 96840 images
# Loaded: 0.268548 seconds
#
#  4843: 0.304416, 0.177163 avg loss, 0.006250 rate, 0.100881 seconds, 96860 images
# Loaded: 0.132754 seconds
#
#  4844: 0.249992, 0.184446 avg loss, 0.006250 rate, 0.113220 seconds, 96880 images
# Loaded: 0.157787 seconds
#
#  4845: 0.162215, 0.182223 avg loss, 0.006250 rate, 0.109985 seconds, 96900 images
# Loaded: 0.117197 seconds
#
#  4846: 0.230362, 0.187037 avg loss, 0.006250 rate, 0.109329 seconds, 96920 images
# Loaded: 0.105971 seconds
#
#  4847: 0.168297, 0.185163 avg loss, 0.006250 rate, 0.113219 seconds, 96940 images
# Loaded: 0.112290 seconds
#
#  4848: 0.124413, 0.179088 avg loss, 0.006250 rate, 0.104488 seconds, 96960 images
# Loaded: 0.182810 seconds
#
#  4849: 0.152486, 0.176428 avg loss, 0.006250 rate, 0.117010 seconds, 96980 images
# Loaded: 0.087193 seconds
#
#  4850: 0.147398, 0.173525 avg loss, 0.006250 rate, 0.116163 seconds, 97000 images
# Resizing
# 416 x 416
#  try to allocate additional workspace_size = 139.49 MB
#  CUDA allocate done!
# Loaded: 0.000039 seconds
#
#  4851: 0.179075, 0.174080 avg loss, 0.006250 rate, 0.144243 seconds, 97020 images
# Loaded: 0.122406 seconds
#
#  4852: 0.120354, 0.168707 avg loss, 0.006250 rate, 0.127154 seconds, 97040 images
# Loaded: 0.173181 seconds
#
#  4853: 0.230580, 0.174894 avg loss, 0.006250 rate, 0.129878 seconds, 97060 images
# Loaded: 0.139537 seconds
#
#  4854: 0.163668, 0.173772 avg loss, 0.006250 rate, 0.126977 seconds, 97080 images
# Loaded: 0.146946 seconds
#
#  4855: 0.207872, 0.177182 avg loss, 0.006250 rate, 0.141251 seconds, 97100 images
# Loaded: 0.059931 seconds
#
#  4856: 0.129109, 0.172375 avg loss, 0.006250 rate, 0.131292 seconds, 97120 images
# Loaded: 0.185047 seconds
#
#  4857: 0.222703, 0.177407 avg loss, 0.006250 rate, 0.132562 seconds, 97140 images
# Loaded: 0.049008 seconds
#
#  4858: 0.169864, 0.176653 avg loss, 0.006250 rate, 0.132764 seconds, 97160 images
# Loaded: 0.149967 seconds
#
#  4859: 0.157432, 0.174731 avg loss, 0.006250 rate, 0.140051 seconds, 97180 images
# Loaded: 0.196954 seconds
#
#  4860: 0.221554, 0.179413 avg loss, 0.006250 rate, 0.138396 seconds, 97200 images
# Resizing
# 544 x 544
#  try to allocate additional workspace_size = 238.53 MB
#  CUDA allocate done!
# Loaded: 0.000042 seconds
#
#  4861: 0.360131, 0.197485 avg loss, 0.006250 rate, 0.234099 seconds, 97220 images
# Loaded: 0.123893 seconds
#
#  4862: 0.436156, 0.221352 avg loss, 0.006250 rate, 0.249365 seconds, 97240 images
# Loaded: 0.110320 seconds
#
#  4863: 0.488369, 0.248054 avg loss, 0.006250 rate, 0.227051 seconds, 97260 images
# Loaded: 0.076967 seconds
#
#  4864: 0.488390, 0.272087 avg loss, 0.006250 rate, 0.270397 seconds, 97280 images
# Loaded: 0.087330 seconds
#
#  4865: 0.373800, 0.282259 avg loss, 0.006250 rate, 0.231547 seconds, 97300 images
# Loaded: 0.146633 seconds
#
#  4866: 0.498086, 0.303841 avg loss, 0.006250 rate, 0.257659 seconds, 97320 images
# Loaded: 0.047408 seconds
#
#  4867: 0.434239, 0.316881 avg loss, 0.006250 rate, 0.246252 seconds, 97340 images
# Loaded: 0.000174 seconds
#
#  4868: 0.320095, 0.317202 avg loss, 0.006250 rate, 0.286847 seconds, 97360 images
# Loaded: 0.013570 seconds
#
#  4869: 0.432150, 0.328697 avg loss, 0.006250 rate, 0.289155 seconds, 97380 images
# Loaded: 0.098562 seconds
#
#  4870: 0.304323, 0.326260 avg loss, 0.006250 rate, 0.231445 seconds, 97400 images
# Resizing
# 416 x 416
#  try to allocate additional workspace_size = 139.49 MB
#  CUDA allocate done!
# Loaded: 0.074690 seconds
#
#  4871: 0.206707, 0.314305 avg loss, 0.006250 rate, 0.147093 seconds, 97420 images
# Loaded: 0.236363 seconds
#
#  4872: 0.199468, 0.302821 avg loss, 0.006250 rate, 0.139203 seconds, 97440 images
# Loaded: 0.170131 seconds
#
#  4873: 0.177717, 0.290311 avg loss, 0.006250 rate, 0.135208 seconds, 97460 images
# Loaded: 0.093015 seconds
#
#  4874: 0.214268, 0.282706 avg loss, 0.006250 rate, 0.133921 seconds, 97480 images
# Loaded: 0.093623 seconds
#
#  4875: 0.258674, 0.280303 avg loss, 0.006250 rate, 0.128939 seconds, 97500 images
# Loaded: 0.166992 seconds
#
#  4876: 0.147151, 0.266988 avg loss, 0.006250 rate, 0.139265 seconds, 97520 images
# Loaded: 0.102136 seconds
#
#  4877: 0.126374, 0.252927 avg loss, 0.006250 rate, 0.140342 seconds, 97540 images
# Loaded: 0.083215 seconds
#
#  4878: 0.227998, 0.250434 avg loss, 0.006250 rate, 0.130707 seconds, 97560 images
# Loaded: 0.072154 seconds
#
#  4879: 0.201512, 0.245541 avg loss, 0.006250 rate, 0.131012 seconds, 97580 images
# Loaded: 0.148382 seconds
#
#  4880: 0.217191, 0.242706 avg loss, 0.006250 rate, 0.133991 seconds, 97600 images
# Resizing
# 384 x 384
#  try to allocate additional workspace_size = 118.85 MB
#  CUDA allocate done!
# Loaded: 0.000047 seconds
#
#  4881: 0.223818, 0.240818 avg loss, 0.006250 rate, 0.106874 seconds, 97620 images
# Loaded: 0.223747 seconds
#
#  4882: 0.214701, 0.238206 avg loss, 0.006250 rate, 0.109682 seconds, 97640 images
# Loaded: 0.192306 seconds
#
#  4883: 0.238734, 0.238259 avg loss, 0.006250 rate, 0.109328 seconds, 97660 images
# Loaded: 0.145587 seconds
#
#  4884: 0.204255, 0.234858 avg loss, 0.006250 rate, 0.114614 seconds, 97680 images
# Loaded: 0.186451 seconds
#
#  4885: 0.161109, 0.227483 avg loss, 0.006250 rate, 0.103224 seconds, 97700 images
# Loaded: 0.085583 seconds
#
#  4886: 0.259369, 0.230672 avg loss, 0.006250 rate, 0.107184 seconds, 97720 images
# Loaded: 0.112262 seconds
#
#  4887: 0.261070, 0.233712 avg loss, 0.006250 rate, 0.112044 seconds, 97740 images
# Loaded: 0.082813 seconds
#
#  4888: 0.214502, 0.231791 avg loss, 0.006250 rate, 0.110384 seconds, 97760 images
# Loaded: 0.167994 seconds
#
#  4889: 0.144156, 0.223027 avg loss, 0.006250 rate, 0.107783 seconds, 97780 images
# Loaded: 0.175567 seconds
#
#  4890: 0.276721, 0.228397 avg loss, 0.006250 rate, 0.103049 seconds, 97800 images
# Resizing
# 352 x 352
#  try to allocate additional workspace_size = 99.87 MB
#  CUDA allocate done!
# Loaded: 0.075040 seconds
#
#  4891: 0.176857, 0.223243 avg loss, 0.006250 rate, 0.086922 seconds, 97820 images
# Loaded: 0.119022 seconds
#
#  4892: 0.173472, 0.218266 avg loss, 0.006250 rate, 0.089600 seconds, 97840 images
# Loaded: 0.116460 seconds
#
#  4893: 0.177523, 0.214191 avg loss, 0.006250 rate, 0.092366 seconds, 97860 images
# Loaded: 0.085285 seconds
#
#  4894: 0.145992, 0.207372 avg loss, 0.006250 rate, 0.098597 seconds, 97880 images
# Loaded: 0.192299 seconds
#
#  4895: 0.080236, 0.194658 avg loss, 0.006250 rate, 0.101179 seconds, 97900 images
# Loaded: 0.223055 seconds
#
#  4896: 0.117131, 0.186905 avg loss, 0.006250 rate, 0.091892 seconds, 97920 images
# Loaded: 0.083675 seconds
#
#  4897: 0.155412, 0.183756 avg loss, 0.006250 rate, 0.094372 seconds, 97940 images
# Loaded: 0.118191 seconds
#
#  4898: 0.086155, 0.173996 avg loss, 0.006250 rate, 0.091343 seconds, 97960 images
# Loaded: 0.186221 seconds
#
#  4899: 0.118389, 0.168435 avg loss, 0.006250 rate, 0.103893 seconds, 97980 images
# Loaded: 0.123120 seconds
#
#  4900: 0.129098, 0.164502 avg loss, 0.006250 rate, 0.091594 seconds, 98000 images
# Saving weights to /content/gdrive/My Drive/darknet/backup/yolov3-tiny_last.weights
# Resizing
# 352 x 352
#  try to allocate additional workspace_size = 99.87 MB
#  CUDA allocate done!
# Loaded: 0.259113 seconds
#
#  4901: 0.121280, 0.160179 avg loss, 0.006250 rate, 0.094008 seconds, 98020 images
# Loaded: 0.115623 seconds
#
#  4902: 0.232793, 0.167441 avg loss, 0.006250 rate, 0.089076 seconds, 98040 images
# Loaded: 0.074353 seconds
#
#  4903: 0.159801, 0.166677 avg loss, 0.006250 rate, 0.084409 seconds, 98060 images
# Loaded: 0.168325 seconds
#
#  4904: 0.186259, 0.168635 avg loss, 0.006250 rate, 0.096469 seconds, 98080 images
# Loaded: 0.163133 seconds
#
#  4905: 0.137102, 0.165482 avg loss, 0.006250 rate, 0.103889 seconds, 98100 images
# Loaded: 0.084261 seconds
#
#  4906: 0.150961, 0.164030 avg loss, 0.006250 rate, 0.090381 seconds, 98120 images
# Loaded: 0.108670 seconds
#
#  4907: 0.175987, 0.165225 avg loss, 0.006250 rate, 0.090262 seconds, 98140 images
# Loaded: 0.169704 seconds
#
#  4908: 0.178636, 0.166566 avg loss, 0.006250 rate, 0.090833 seconds, 98160 images
# Loaded: 0.105465 seconds
#
#  4909: 0.148824, 0.164792 avg loss, 0.006250 rate, 0.095060 seconds, 98180 images
# Loaded: 0.124700 seconds
#
#  4910: 0.158401, 0.164153 avg loss, 0.006250 rate, 0.092114 seconds, 98200 images
# Resizing
# 608 x 608
#  try to allocate additional workspace_size = 297.95 MB
#  CUDA allocate done!
# Loaded: 0.000042 seconds
#
#  4911: 0.960909, 0.243829 avg loss, 0.006250 rate, 0.250668 seconds, 98220 images
# Loaded: 0.102180 seconds
#
#  4912: 0.912889, 0.310735 avg loss, 0.006250 rate, 0.284315 seconds, 98240 images
# Loaded: 0.082308 seconds
#
#  4913: 0.711967, 0.350858 avg loss, 0.006250 rate, 0.289329 seconds, 98260 images
# Loaded: 0.049240 seconds
#
#  4914: 0.787278, 0.394500 avg loss, 0.006250 rate, 0.303726 seconds, 98280 images
# Loaded: 0.035045 seconds
#
#  4915: 0.590785, 0.414128 avg loss, 0.006250 rate, 0.290602 seconds, 98300 images
# Loaded: 0.075376 seconds
#
#  4916: 0.363004, 0.409016 avg loss, 0.006250 rate, 0.268017 seconds, 98320 images
# Loaded: 0.131421 seconds
#
#  4917: 0.437386, 0.411853 avg loss, 0.006250 rate, 0.282700 seconds, 98340 images
# Loaded: 0.009680 seconds
#
#  4918: 0.492801, 0.419948 avg loss, 0.006250 rate, 0.327464 seconds, 98360 images
# Loaded: 0.000037 seconds
#
#  4919: 0.424142, 0.420367 avg loss, 0.006250 rate, 0.304818 seconds, 98380 images
# Loaded: 0.000034 seconds
#
#  4920: 0.344853, 0.412816 avg loss, 0.006250 rate, 0.330442 seconds, 98400 images
# Resizing
# 544 x 544
#  try to allocate additional workspace_size = 238.53 MB
#  CUDA allocate done!
# Loaded: 0.032786 seconds
#
#  4921: 0.326883, 0.404223 avg loss, 0.006250 rate, 0.228167 seconds, 98420 images
# Loaded: 0.068007 seconds
#
#  4922: 0.493645, 0.413165 avg loss, 0.006250 rate, 0.253086 seconds, 98440 images
# Loaded: 0.037338 seconds
#
#  4923: 0.390400, 0.410888 avg loss, 0.006250 rate, 0.259914 seconds, 98460 images
# Loaded: 0.075581 seconds
#
#  4924: 0.497327, 0.419532 avg loss, 0.006250 rate, 0.237873 seconds, 98480 images
# Loaded: 0.081535 seconds
#
#  4925: 0.376797, 0.415259 avg loss, 0.006250 rate, 0.234770 seconds, 98500 images
# Loaded: 0.062417 seconds
#
#  4926: 0.350155, 0.408748 avg loss, 0.006250 rate, 0.227191 seconds, 98520 images
# Loaded: 0.053411 seconds
#
#  4927: 0.356047, 0.403478 avg loss, 0.006250 rate, 0.240566 seconds, 98540 images
# Loaded: 0.049928 seconds
#
#  4928: 0.374720, 0.400602 avg loss, 0.006250 rate, 0.241069 seconds, 98560 images
# Loaded: 0.078469 seconds
#
#  4929: 0.388205, 0.399363 avg loss, 0.006250 rate, 0.248047 seconds, 98580 images
# Loaded: 0.021898 seconds
#
#  4930: 0.341466, 0.393573 avg loss, 0.006250 rate, 0.263630 seconds, 98600 images
# Resizing
# 352 x 352
#  try to allocate additional workspace_size = 99.87 MB
#  CUDA allocate done!
# Loaded: 0.000044 seconds
#
#  4931: 0.295831, 0.383799 avg loss, 0.006250 rate, 0.100273 seconds, 98620 images
# Loaded: 0.111550 seconds
#
#  4932: 0.214865, 0.366905 avg loss, 0.006250 rate, 0.092752 seconds, 98640 images
# Loaded: 0.127543 seconds
#
#  4933: 0.178956, 0.348110 avg loss, 0.006250 rate, 0.088874 seconds, 98660 images
# Loaded: 0.192360 seconds
#
#  4934: 0.164840, 0.329783 avg loss, 0.006250 rate, 0.090445 seconds, 98680 images
# Loaded: 0.202094 seconds
#
#  4935: 0.208322, 0.317637 avg loss, 0.006250 rate, 0.091371 seconds, 98700 images
# Loaded: 0.190717 seconds
#
#  4936: 0.175505, 0.303424 avg loss, 0.006250 rate, 0.096932 seconds, 98720 images
# Loaded: 0.169071 seconds
#
#  4937: 0.174084, 0.290490 avg loss, 0.006250 rate, 0.103089 seconds, 98740 images
# Loaded: 0.290675 seconds
#
#  4938: 0.129376, 0.274379 avg loss, 0.006250 rate, 0.090661 seconds, 98760 images
# Loaded: 0.200317 seconds
#
# ...
# Loaded: 0.189456 seconds
#
#  5869: 0.205088, 0.183495 avg loss, 0.003125 rate, 0.126458 seconds, 117380 images
# Loaded: 0.197458 seconds
#
#  5870: 0.088445, 0.173990 avg loss, 0.003125 rate, 0.127214 seconds, 117400 images
# Resizing
# 576 x 576
#  try to allocate additional workspace_size = 267.41 MB
#  CUDA allocate done!
# Loaded: 0.000045 seconds
#
#  5871: 0.344656, 0.191057 avg loss, 0.003125 rate, 0.264098 seconds, 117420 images
# Loaded: 0.005327 seconds
#
#  5872: 0.600908, 0.232042 avg loss, 0.003125 rate, 0.300001 seconds, 117440 images
# Loaded: 0.050358 seconds
#
#  5873: 0.442109, 0.253048 avg loss, 0.003125 rate, 0.258251 seconds, 117460 images
# Loaded: 0.000042 seconds
#
#  5874: 0.527537, 0.280497 avg loss, 0.003125 rate, 0.312251 seconds, 117480 images
# Loaded: 0.000033 seconds
#
#  5875: 0.451449, 0.297593 avg loss, 0.003125 rate, 0.305121 seconds, 117500 images
# Loaded: 0.000031 seconds
#
#  5876: 0.301318, 0.297965 avg loss, 0.003125 rate, 0.315872 seconds, 117520 images
# Loaded: 0.000032 seconds
#
#  5877: 0.387707, 0.306939 avg loss, 0.003125 rate, 0.323405 seconds, 117540 images
# Loaded: 0.013226 seconds
#
#  5878: 0.315338, 0.307779 avg loss, 0.003125 rate, 0.296412 seconds, 117560 images
# Loaded: 0.000041 seconds
#
#  5879: 0.270824, 0.304084 avg loss, 0.003125 rate, 0.332868 seconds, 117580 images
# Loaded: 0.019970 seconds
#
#  5880: 0.346036, 0.308279 avg loss, 0.003125 rate, 0.312763 seconds, 117600 images
# Resizing
# 512 x 512
#  try to allocate additional workspace_size = 211.29 MB
#  CUDA allocate done!
# Loaded: 0.223781 seconds
#
#  5881: 0.284999, 0.305951 avg loss, 0.003125 rate, 0.199247 seconds, 117620 images
# Loaded: 0.056793 seconds
#
#  5882: 0.299473, 0.305303 avg loss, 0.003125 rate, 0.178908 seconds, 117640 images
# Loaded: 0.139830 seconds
#
#  5883: 0.309591, 0.305732 avg loss, 0.003125 rate, 0.198035 seconds, 117660 images
# Loaded: 0.032616 seconds
#
#  5884: 0.285132, 0.303672 avg loss, 0.003125 rate, 0.220450 seconds, 117680 images
# Loaded: 0.119570 seconds
#
#  5885: 0.276296, 0.300934 avg loss, 0.003125 rate, 0.201078 seconds, 117700 images
# Loaded: 0.155242 seconds
#
#  5886: 0.288196, 0.299660 avg loss, 0.003125 rate, 0.194579 seconds, 117720 images
# Loaded: 0.149930 seconds
#
#  5887: 0.261068, 0.295801 avg loss, 0.003125 rate, 0.206145 seconds, 117740 images
# Loaded: 0.019054 seconds
#
#  5888: 0.297085, 0.295930 avg loss, 0.003125 rate, 0.217125 seconds, 117760 images
# Loaded: 0.128860 seconds
#
#  5889: 0.234835, 0.289820 avg loss, 0.003125 rate, 0.187833 seconds, 117780 images
# Loaded: 0.237701 seconds
#
#  5890: 0.269357, 0.287774 avg loss, 0.003125 rate, 0.174638 seconds, 117800 images
# Resizing
# 544 x 544
#  try to allocate additional workspace_size = 238.53 MB
#  CUDA allocate done!
# Loaded: 0.000043 seconds
#
#  5891: 0.214539, 0.280450 avg loss, 0.003125 rate, 0.227103 seconds, 117820 images
# Loaded: 0.127911 seconds
#
#  5892: 0.273885, 0.279794 avg loss, 0.003125 rate, 0.244601 seconds, 117840 images
# Loaded: 0.000033 seconds
#
#  5893: 0.339850, 0.285799 avg loss, 0.003125 rate, 0.290294 seconds, 117860 images
# Loaded: 0.133656 seconds
#
#  5894: 0.375721, 0.294792 avg loss, 0.003125 rate, 0.233101 seconds, 117880 images
# Loaded: 0.111962 seconds
#
#  5895: 0.280152, 0.293328 avg loss, 0.003125 rate, 0.252632 seconds, 117900 images
# Loaded: 0.010051 seconds
#
#  5896: 0.274688, 0.291464 avg loss, 0.003125 rate, 0.282208 seconds, 117920 images
# Loaded: 0.082128 seconds
#
#  5897: 0.340356, 0.296353 avg loss, 0.003125 rate, 0.236156 seconds, 117940 images
# Loaded: 0.047527 seconds
#
#  5898: 0.361426, 0.302860 avg loss, 0.003125 rate, 0.258168 seconds, 117960 images
# Loaded: 0.016952 seconds
#
#  5899: 0.354866, 0.308061 avg loss, 0.003125 rate, 0.258887 seconds, 117980 images
# Loaded: 0.128160 seconds
#
#  5900: 0.288558, 0.306110 avg loss, 0.003125 rate, 0.228959 seconds, 118000 images
# Saving weights to /content/gdrive/My Drive/darknet/backup/yolov3-tiny_last.weights
# Resizing
# 416 x 416
#  try to allocate additional workspace_size = 139.49 MB
#  CUDA allocate done!
# Loaded: 0.140132 seconds
#
#  5901: 0.270672, 0.302567 avg loss, 0.003125 rate, 0.131737 seconds, 118020 images
# Loaded: 0.206126 seconds
#
#  5902: 0.168568, 0.289167 avg loss, 0.003125 rate, 0.135088 seconds, 118040 images
# Loaded: 0.082242 seconds
#
#  5903: 0.144969, 0.274747 avg loss, 0.003125 rate, 0.130165 seconds, 118060 images
# Loaded: 0.176187 seconds
#
#  5904: 0.200263, 0.267299 avg loss, 0.003125 rate, 0.139686 seconds, 118080 images
# Loaded: 0.177890 seconds
#
#  5905: 0.150523, 0.255621 avg loss, 0.003125 rate, 0.145496 seconds, 118100 images
# Loaded: 0.121475 seconds
#
#  5906: 0.189766, 0.249036 avg loss, 0.003125 rate, 0.136535 seconds, 118120 images
# Loaded: 0.067227 seconds
#
#  5907: 0.107892, 0.234921 avg loss, 0.003125 rate, 0.129726 seconds, 118140 images
# Loaded: 0.134702 seconds
#
#  5908: 0.134671, 0.224896 avg loss, 0.003125 rate, 0.135550 seconds, 118160 images
# Loaded: 0.139818 seconds
#
#  5909: 0.153109, 0.217718 avg loss, 0.003125 rate, 0.134294 seconds, 118180 images
# Loaded: 0.112474 seconds
#
#  5910: 0.234970, 0.219443 avg loss, 0.003125 rate, 0.130647 seconds, 118200 images
# Resizing
# 448 x 448
#  try to allocate additional workspace_size = 161.77 MB
#  CUDA allocate done!
# Loaded: 0.000040 seconds
#
#  5911: 0.166726, 0.214171 avg loss, 0.003125 rate, 0.152850 seconds, 118220 images
# Loaded: 0.125241 seconds
#
#  5912: 0.178346, 0.210589 avg loss, 0.003125 rate, 0.136505 seconds, 118240 images
# Loaded: 0.118068 seconds
#
#  5913: 0.219111, 0.211441 avg loss, 0.003125 rate, 0.152850 seconds, 118260 images
# Loaded: 0.117060 seconds
#
#  5914: 0.296444, 0.219941 avg loss, 0.003125 rate, 0.148587 seconds, 118280 images
# Loaded: 0.137461 seconds
#
#  5915: 0.199891, 0.217936 avg loss, 0.003125 rate, 0.137074 seconds, 118300 images
# Loaded: 0.178975 seconds
#
#  5916: 0.173360, 0.213479 avg loss, 0.003125 rate, 0.142791 seconds, 118320 images
# Loaded: 0.084168 seconds
#
#  5917: 0.195641, 0.211695 avg loss, 0.003125 rate, 0.156040 seconds, 118340 images
# Loaded: 0.188148 seconds
#
#  5918: 0.170923, 0.207618 avg loss, 0.003125 rate, 0.138021 seconds, 118360 images
# Loaded: 0.233202 seconds
#
#  5919: 0.130073, 0.199863 avg loss, 0.003125 rate, 0.138942 seconds, 118380 images
# Loaded: 0.112119 seconds
#
#  5920: 0.308864, 0.210763 avg loss, 0.003125 rate, 0.142764 seconds, 118400 images
# Resizing
# 448 x 448
#  try to allocate additional workspace_size = 161.77 MB
#  CUDA allocate done!
# Loaded: 0.235388 seconds
#
#  5921: 0.206888, 0.210376 avg loss, 0.003125 rate, 0.158506 seconds, 118420 images
# Loaded: 0.077741 seconds
#
#  5922: 0.176633, 0.207001 avg loss, 0.003125 rate, 0.141251 seconds, 118440 images
# Loaded: 0.190887 seconds
#
#  5923: 0.090925, 0.195394 avg loss, 0.003125 rate, 0.151916 seconds, 118460 images
# Loaded: 0.124645 seconds
#
#  5924: 0.260229, 0.201877 avg loss, 0.003125 rate, 0.154936 seconds, 118480 images
# Loaded: 0.142780 seconds
#
#  5925: 0.190436, 0.200733 avg loss, 0.003125 rate, 0.151263 seconds, 118500 images
# Loaded: 0.153562 seconds
#
#  5926: 0.364077, 0.217068 avg loss, 0.003125 rate, 0.137131 seconds, 118520 images
# Loaded: 0.148936 seconds
#
#  5927: 0.131882, 0.208549 avg loss, 0.003125 rate, 0.138234 seconds, 118540 images
# Loaded: 0.110001 seconds
#
#  5928: 0.264173, 0.214112 avg loss, 0.003125 rate, 0.146491 seconds, 118560 images
# Loaded: 0.227342 seconds
#
#  5929: 0.212241, 0.213924 avg loss, 0.003125 rate, 0.150602 seconds, 118580 images
# Loaded: 0.204230 seconds
#
#  5930: 0.178714, 0.210403 avg loss, 0.003125 rate, 0.144250 seconds, 118600 images
# Resizing
# 384 x 384
#  try to allocate additional workspace_size = 118.85 MB
#  CUDA allocate done!
# Loaded: 0.000043 seconds
#
#  5931: 0.219577, 0.211321 avg loss, 0.003125 rate, 0.108690 seconds, 118620 images
# Loaded: 0.092942 seconds
#
#  5932: 0.183433, 0.208532 avg loss, 0.003125 rate, 0.116496 seconds, 118640 images
# Loaded: 0.213931 seconds
#
#  5933: 0.209147, 0.208593 avg loss, 0.003125 rate, 0.101705 seconds, 118660 images
# Loaded: 0.204114 seconds
#
#  5934: 0.104214, 0.198155 avg loss, 0.003125 rate, 0.105115 seconds, 118680 images
# Loaded: 0.151378 seconds
#
#  5935: 0.148634, 0.193203 avg loss, 0.003125 rate, 0.108335 seconds, 118700 images
# Loaded: 0.179565 seconds
#
#  5936: 0.187664, 0.192649 avg loss, 0.003125 rate, 0.116601 seconds, 118720 images
# Loaded: 0.115553 seconds
#
#  5937: 0.180447, 0.191429 avg loss, 0.003125 rate, 0.108313 seconds, 118740 images
# Loaded: 0.088686 seconds
#
#  5938: 0.147594, 0.187046 avg loss, 0.003125 rate, 0.104123 seconds, 118760 images
# Loaded: 0.138146 seconds
#
#  5939: 0.167715, 0.185113 avg loss, 0.003125 rate, 0.107433 seconds, 118780 images
# Loaded: 0.167302 seconds
#
#  5940: 0.166105, 0.183212 avg loss, 0.003125 rate, 0.106401 seconds, 118800 images
# Resizing
# 576 x 576
#  try to allocate additional workspace_size = 267.41 MB
#  CUDA allocate done!
# Loaded: 0.000042 seconds
#
#  5941: 0.363874, 0.201278 avg loss, 0.003125 rate, 0.242449 seconds, 118820 images
# Loaded: 0.107951 seconds
#
#  5942: 0.453982, 0.226548 avg loss, 0.003125 rate, 0.282488 seconds, 118840 images
# Loaded: 0.000038 seconds
#
#  5943: 0.421010, 0.245995 avg loss, 0.003125 rate, 0.301232 seconds, 118860 images
# Loaded: 0.000032 seconds
#
#  5944: 0.395786, 0.260974 avg loss, 0.003125 rate, 0.300382 seconds, 118880 images
# Loaded: 0.000031 seconds
#
#  5945: 0.477611, 0.282637 avg loss, 0.003125 rate, 0.306965 seconds, 118900 images
# Loaded: 0.000036 seconds
#
#  5946: 0.366960, 0.291070 avg loss, 0.003125 rate, 0.321271 seconds, 118920 images
# Loaded: 0.105171 seconds
#
#  5947: 0.447207, 0.306683 avg loss, 0.003125 rate, 0.279884 seconds, 118940 images
# Loaded: 0.132794 seconds
#
#  5948: 0.322138, 0.308229 avg loss, 0.003125 rate, 0.276648 seconds, 118960 images
# Loaded: 0.003301 seconds
#
#  5949: 0.336295, 0.311035 avg loss, 0.003125 rate, 0.311071 seconds, 118980 images
# Loaded: 0.038281 seconds
#
#  5950: 0.374625, 0.317394 avg loss, 0.003125 rate, 0.299549 seconds, 119000 images
# Resizing
# 416 x 416
#  try to allocate additional workspace_size = 139.49 MB
#  CUDA allocate done!
# Loaded: 0.139145 seconds
#
#  5951: 0.151433, 0.300798 avg loss, 0.003125 rate, 0.128681 seconds, 119020 images
# Loaded: 0.116676 seconds
#
#  5952: 0.261097, 0.296828 avg loss, 0.003125 rate, 0.138534 seconds, 119040 images
# Loaded: 0.074444 seconds
#
#  5953: 0.116526, 0.278798 avg loss, 0.003125 rate, 0.125802 seconds, 119060 images
# Loaded: 0.114092 seconds
#
#  5954: 0.146926, 0.265611 avg loss, 0.003125 rate, 0.127555 seconds, 119080 images
# Loaded: 0.278654 seconds
#
#  5955: 0.200675, 0.259117 avg loss, 0.003125 rate, 0.127002 seconds, 119100 images
# Loaded: 0.237008 seconds
#
#  5956: 0.248369, 0.258042 avg loss, 0.003125 rate, 0.131548 seconds, 119120 images
# Loaded: 0.141380 seconds
#
#  5957: 0.205681, 0.252806 avg loss, 0.003125 rate, 0.127030 seconds, 119140 images
# Loaded: 0.159550 seconds
#
#  5958: 0.178191, 0.245345 avg loss, 0.003125 rate, 0.138443 seconds, 119160 images
# Loaded: 0.069548 seconds
#
#  5959: 0.140535, 0.234864 avg loss, 0.003125 rate, 0.130913 seconds, 119180 images
# Loaded: 0.117136 seconds
#
#  5960: 0.174825, 0.228860 avg loss, 0.003125 rate, 0.135643 seconds, 119200 images
# Resizing
# 448 x 448
#  try to allocate additional workspace_size = 161.77 MB
#  CUDA allocate done!
# Loaded: 0.000043 seconds
#
#  5961: 0.206822, 0.226656 avg loss, 0.003125 rate, 0.141871 seconds, 119220 images
# Loaded: 0.197737 seconds
#
#  5962: 0.323419, 0.236332 avg loss, 0.003125 rate, 0.144855 seconds, 119240 images
# Loaded: 0.212480 seconds
#
#  5963: 0.175817, 0.230281 avg loss, 0.003125 rate, 0.146952 seconds, 119260 images
# Loaded: 0.278408 seconds
#
#  5964: 0.178906, 0.225143 avg loss, 0.003125 rate, 0.146661 seconds, 119280 images
# Loaded: 0.132693 seconds
#
#  5965: 0.364645, 0.239094 avg loss, 0.003125 rate, 0.148055 seconds, 119300 images
# Loaded: 0.145580 seconds
#
#  5966: 0.215877, 0.236772 avg loss, 0.003125 rate, 0.140735 seconds, 119320 images
# Loaded: 0.066566 seconds
#
#  5967: 0.204323, 0.233527 avg loss, 0.003125 rate, 0.163249 seconds, 119340 images
# Loaded: 0.116109 seconds
#
#  5968: 0.194869, 0.229661 avg loss, 0.003125 rate, 0.136399 seconds, 119360 images
# Loaded: 0.146640 seconds
#
#  5969: 0.195074, 0.226203 avg loss, 0.003125 rate, 0.142567 seconds, 119380 images
# Loaded: 0.159910 seconds
#
#  5970: 0.152194, 0.218802 avg loss, 0.003125 rate, 0.147201 seconds, 119400 images
# Resizing
# 448 x 448
#  try to allocate additional workspace_size = 161.77 MB
#  CUDA allocate done!
# Loaded: 0.165252 seconds
#
#  5971: 0.346872, 0.231609 avg loss, 0.003125 rate, 0.152895 seconds, 119420 images
# Loaded: 0.134761 seconds
#
#  5972: 0.218360, 0.230284 avg loss, 0.003125 rate, 0.149123 seconds, 119440 images
# Loaded: 0.079270 seconds
#
#  5973: 0.193692, 0.226625 avg loss, 0.003125 rate, 0.155262 seconds, 119460 images
# Loaded: 0.117295 seconds
#
#  5974: 0.231481, 0.227110 avg loss, 0.003125 rate, 0.159204 seconds, 119480 images
# Loaded: 0.201536 seconds
#
#  5975: 0.227139, 0.227113 avg loss, 0.003125 rate, 0.142035 seconds, 119500 images
# Loaded: 0.157372 seconds
#
#  5976: 0.152654, 0.219667 avg loss, 0.003125 rate, 0.149546 seconds, 119520 images
# Loaded: 0.055848 seconds
#
#  5977: 0.237922, 0.221493 avg loss, 0.003125 rate, 0.150853 seconds, 119540 images
# Loaded: 0.161058 seconds
#
#  5978: 0.195617, 0.218905 avg loss, 0.003125 rate, 0.149654 seconds, 119560 images
# Loaded: 0.140642 seconds
#
#  5979: 0.149078, 0.211922 avg loss, 0.003125 rate, 0.135198 seconds, 119580 images
# Loaded: 0.205017 seconds
#
#  5980: 0.145182, 0.205248 avg loss, 0.003125 rate, 0.144514 seconds, 119600 images
# Resizing
# 480 x 480
#  try to allocate additional workspace_size = 185.70 MB
#  CUDA allocate done!
# Loaded: 0.000038 seconds
#
#  5981: 0.245162, 0.209240 avg loss, 0.003125 rate, 0.160094 seconds, 119620 images
# Loaded: 0.117993 seconds
#
#  5982: 0.159775, 0.204293 avg loss, 0.003125 rate, 0.169986 seconds, 119640 images
# Loaded: 0.136117 seconds
#
#  5983: 0.200071, 0.203871 avg loss, 0.003125 rate, 0.175104 seconds, 119660 images
# Loaded: 0.124789 seconds
#
#  5984: 0.277783, 0.211262 avg loss, 0.003125 rate, 0.169065 seconds, 119680 images
# Loaded: 0.048703 seconds
#
#  5985: 0.224881, 0.212624 avg loss, 0.003125 rate, 0.172245 seconds, 119700 images
# Loaded: 0.154291 seconds
#
#  5986: 0.164366, 0.207798 avg loss, 0.003125 rate, 0.159210 seconds, 119720 images
# Loaded: 0.187430 seconds
#
#  5987: 0.174382, 0.204457 avg loss, 0.003125 rate, 0.164657 seconds, 119740 images
# Loaded: 0.130243 seconds
#
#  5988: 0.140137, 0.198025 avg loss, 0.003125 rate, 0.159725 seconds, 119760 images
# Loaded: 0.111725 seconds
#
#  5989: 0.124241, 0.190646 avg loss, 0.003125 rate, 0.190297 seconds, 119780 images
# Loaded: 0.232639 seconds
#
#  5990: 0.166210, 0.188203 avg loss, 0.003125 rate, 0.161386 seconds, 119800 images
# Resizing
# 352 x 352
#  try to allocate additional workspace_size = 99.87 MB
#  CUDA allocate done!
# Loaded: 0.000038 seconds
#
#  5991: 0.147126, 0.184095 avg loss, 0.003125 rate, 0.093901 seconds, 119820 images
# Loaded: 0.229100 seconds
#
#  5992: 0.114476, 0.177133 avg loss, 0.003125 rate, 0.089384 seconds, 119840 images
# Loaded: 0.166253 seconds
#
#  5993: 0.119372, 0.171357 avg loss, 0.003125 rate, 0.090610 seconds, 119860 images
# Loaded: 0.191806 seconds
#
#  5994: 0.095976, 0.163819 avg loss, 0.003125 rate, 0.094002 seconds, 119880 images
# Loaded: 0.072142 seconds
#
#  5995: 0.103347, 0.157772 avg loss, 0.003125 rate, 0.089805 seconds, 119900 images
# Loaded: 0.107560 seconds
#
#  5996: 0.129760, 0.154971 avg loss, 0.003125 rate, 0.092505 seconds, 119920 images
# Loaded: 0.286404 seconds
#
#  5997: 0.115358, 0.151009 avg loss, 0.003125 rate, 0.089421 seconds, 119940 images
# Loaded: 0.112951 seconds
#
#  5998: 0.090711, 0.144980 avg loss, 0.003125 rate, 0.088382 seconds, 119960 images
# Loaded: 0.259458 seconds
#
#  5999: 0.113285, 0.141810 avg loss, 0.003125 rate, 0.088399 seconds, 119980 images
# Loaded: 0.000038 seconds
#
#  6000: 0.098319, 0.137461 avg loss, 0.001563 rate, 0.091011 seconds, 120000 images
# Saving weights to /content/gdrive/My Drive/darknet/backup/yolov3-tiny_6000.weights
# Saving weights to /content/gdrive/My Drive/darknet/backup/yolov3-tiny_last.weights
# Saving weights to /content/gdrive/My Drive/darknet/backup/yolov3-tiny_final.weights

# %%
# !./darknet detector map -points 0 "/content/gdrive/MyDrive/darknet/obj.data" "/content/gdrive/MyDrive/darknet/yolov3-tiny.cfg" "/content/gdrive/MyDrive/darknet/backup/yolov3-tiny_final.weights"
# Out:
# valid: Using default 'data/train.txt'
# layer     filters    size              input                output
#    0 conv     16  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  16 0.150 BF
#    1 max          2 x 2 / 2   416 x 416 x  16   ->   208 x 208 x  16 0.003 BF
#    2 conv     32  3 x 3 / 1   208 x 208 x  16   ->   208 x 208 x  32 0.399 BF
#    3 max          2 x 2 / 2   208 x 208 x  32   ->   104 x 104 x  32 0.001 BF
#    4 conv     64  3 x 3 / 1   104 x 104 x  32   ->   104 x 104 x  64 0.399 BF
#    5 max          2 x 2 / 2   104 x 104 x  64   ->    52 x  52 x  64 0.001 BF
#    6 conv    128  3 x 3 / 1    52 x  52 x  64   ->    52 x  52 x 128 0.399 BF
#    7 max          2 x 2 / 2    52 x  52 x 128   ->    26 x  26 x 128 0.000 BF
#    8 conv    256  3 x 3 / 1    26 x  26 x 128   ->    26 x  26 x 256 0.399 BF
#    9 max          2 x 2 / 2    26 x  26 x 256   ->    13 x  13 x 256 0.000 BF
#   10 conv    512  3 x 3 / 1    13 x  13 x 256   ->    13 x  13 x 512 0.399 BF
#   11 max          2 x 2 / 1    13 x  13 x 512   ->    13 x  13 x 512 0.000 BF
#   12 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024 1.595 BF
#   13 conv    256  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 256 0.089 BF
#   14 conv    512  3 x 3 / 1    13 x  13 x 256   ->    13 x  13 x 512 0.399 BF
#   15 conv     18  1 x 1 / 1    13 x  13 x 512   ->    13 x  13 x  18 0.003 BF
#   16 yolo
#   17 route  13
#   18 conv    128  1 x 1 / 1    13 x  13 x 256   ->    13 x  13 x 128 0.011 BF
#   19 upsample            2x    13 x  13 x 128   ->    26 x  26 x 128
#   20 route  19 8
#   21 conv    256  3 x 3 / 1    26 x  26 x 384   ->    26 x  26 x 256 1.196 BF
#   22 conv     18  1 x 1 / 1    26 x  26 x 256   ->    26 x  26 x  18 0.006 BF
#   23 yolo
# Total BFLOPS 5.448
#  Allocate additional workspace_size = 52.43 MB
# Loading weights from /content/gdrive/MyDrive/darknet/backup/yolov3-tiny_final.weights...
#  seen 64
# Done!
#
#  calculation mAP (mean average precision)...
# 24
#  detections_count = 21, unique_truth_count = 21
# class_id = 0, name = Person, ap = 95.24%   	 (TP = 21, FP = 0)
#
#  for thresh = 0.25, precision = 1.00, recall = 1.00, F1-score = 1.00
#  for thresh = 0.25, TP = 21, FP = 0, FN = 0, average IoU = 87.07 %
#
#  IoU threshold = 50 %, used Area-Under-Curve for each unique Recall
#  mean average precision (mAP@0.50) = 0.952381, or 95.24 %
# Total Detection Time: 0.000000 Seconds
#
# Set -points flag:
#  `-points 101` for MS COCO
#  `-points 11` for PascalVOC 2007 (uncomment `difficult` in voc.data)
#  `-points 0` (AUC) for ImageNet, PascalVOC 2010-2012, your custom dataset
